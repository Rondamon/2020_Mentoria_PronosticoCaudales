# %% [markdown]
# ## CONSIGNA TP2:
#
# ## 1. Análisis y curación de datos de una API - formato JSON
#
# Referencias: https://darksky.net/dev/docs
#
#   1. Extraer los datos para la localidad Santa Rosa de Calamuchita para el período 1/Mayo/2018 al 01/Mayo/2020.
#   2. ¿Existen valores faltantes? Cuantificarlos.
#   3. Generar un nuevo dataset a partir de los datos (time, summary, precipAccumulation, temperature, humidity, pressure, windSpeed, uvIndex, temperatureMin, temperatureMax.
#   4. Hacer las conversiones de unidades necesarias a estos datos para poder compararlos con "APRHi - Sta Rosa de Calamuchita".
#   5. Comparar los estadísticos de estos datasets con los de "APRHi - Sta Rosa de Calamuchita".
#
#
# ## 2. Análisis y curación de datos Scrapeados de WeatherUnderground
#
# Referencias: https://www.wunderground.com/
#
#   1. Extraer los datos para la estación meteorológica personal (PWS, por siglas en inglés) "ICALAMUC5" (en Villa General Belgrano), para el período 1/Mayo/2018 al 01/Mayo/2020 mediante el Scrappeo de WeatherUnderground (WU).
#   2. ¿Existen valores faltantes? Cuantificarlos.
#   3. Convertir los datos faltantes en NaN.
#   4. Hacer las conversiones de unidades necesarias a estos datos para poder compararlos con "APRHi - Sta Rosa de Calamuchita".
#   5. Comparar los estadísticos de este dataset con los de "APRHi - Sta Rosa de Calamuchita".
#
#
# ## 3. Análisis y curación de datos de un Excel y un TXT
#
# Referencias GLDAS: https://ldas.gsfc.nasa.gov/gldas
# Referencias IMERG: https://disasters.nasa.gov/instruments/imerg
#
#   1. Leer los datos de GLDAS_SantaRosa.xlsx para el período 1/Mayo/2018 al 31/Abril/2020.
#   2. Leer los datos de IMERG_SantaRosa.txt para el período 1/Mayo/2018 al 31/Abril/2020.
#   3. Hacer las conversiones de unidades necesarias a GLDAS para poder compararlos con "APRHi - Sta Rosa de Calamuchita".
#   4. Comparar los estadísticos de estos datasets con los de "APRHi - Sta Rosa de Calamuchita".
#
#
# ## 4. Rellenar datos faltantes
#   1. ¿De todos los datasets comparados, para cada variable cuál se parece más a los de "APRHi - Sta Rosa de Calamuchita"?
#   2. Acumular las lluvias y promediar las demás variables de "APRHi - Sta Rosa de Calamuchita" cada 30 minutos.
#   3. Interpolar los datos ya procesados de las mejores fuentes de información "alternativas" (salvo las lluvias), cada 30 minutos.
#   4. Hacer lo mismo que en el punto anterior pero para la mejor fuente "alternativa" de lluvias, dividiendo por el número de "time-steps" equivalentes para llevar a cada dato a 30 minutos. (HINT: si la mejor es IMERG, no hacer nada ;D).
#   5. Interpolar el dataset "APRHi - Sta Rosa de Calamuchita" para rellenar los huecos.
#   6. Por otro lado, utilizar lo hecho en los punto 3 y 4 para rellenar los datos faltantes en la estación de "APRHi - Sta Rosa de Calamuchita".
#   7. Exportar los dos datasets nuevos en formato csv.

# %% [markdown]
# ## 1. Análisis y curación de datos de una API - formato JSON
#
# Referencias: https://darksky.net/dev/docs
#
#   1. Extraer los datos para la localidad Santa Rosa de Calamuchita para el período 1/Mayo/2018 al 01/Mayo/2020.
#   2. ¿Existen valores faltantes? Cuantificarlos.
#   3. Generar un nuevo dataset a partir de los datos (time, summary, precipAccumulation, temperature, humidity, pressure, windSpeed, uvIndex, temperatureMin, temperatureMax.
#   4. Hacer las conversiones de unidades necesarias a estos datos para poder compararlos con "APRHi - Sta Rosa de Calamuchita".
#   5. Comparar los estadísticos de estos datasets con los de "APRHi - Sta Rosa de Calamuchita".rte 1

# %%
import datetime
import requests
import pandas as pd
import json
from pandas import json_normalize
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# This function returns a list of date between to boundaries. Source: https://stackoverflow.com/questions/1060279/iterating-through-a-range-of-dates-in-python
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + datetime.timedelta(n)

# %%
baseUrl = "https://api.darksky.net/forecast/<key>/<longitude>,<latitude>,<date>?exclude=flags,hourly&units=ca"

# %%
"""
En este bloque se descarga la data y se la escribe en un archivo.
OJO! Cada vez que se ejecuta la funcion se sobre escribe el archivo con la data scrapeada.
"""

start_date = datetime.datetime(2018, 5, 1)
end_date = datetime.datetime(2020, 5, 1)

data = []
for date in daterange(start_date, end_date):
    tmstmp = str(int(date.timestamp()))
    replacedUrl = baseUrl.replace("<key>", "9349598e9f11f5eddceb6791daa6d787").replace("<longitude>", "-64.533333").replace("<latitude>", "-32.066667").replace("<date>",tmstmp)
    r = requests.get(url = replacedUrl)
    # json with day data
    partial_data = r.json()
    data.append(partial_data)
# writing json
with open('sta_rosa_scraped.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
with open('sta_rosa_scraped.json') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525143600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525230000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525316400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525402800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525489200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525575600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525662000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525748400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525834800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525921200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526007600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526094000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526180400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526266800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526353200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526439600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526526000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526612400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526698800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526785200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526871600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526958000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527044400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527130800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527217200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527303600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527390000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527476400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527562800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527649200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527735600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527822000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527908400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527994800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528081200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528167600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528254000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528340400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528426800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528513200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528599600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528686000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528772400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528858800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528945200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529031600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529118000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529204400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529290800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529377200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529463600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529550000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529636400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529722800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529809200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529895600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529982000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530068400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530154800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530241200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530327600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530414000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530500400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530586800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530673200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530759600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530846000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530932400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531018800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531105200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531191600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531278000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531364400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531450800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531537200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531623600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531710000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531796400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531882800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531969200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532055600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532142000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532228400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532314800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532401200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532487600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532574000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532660400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532746800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532833200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532919600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533006000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533092400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533178800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533265200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533351600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533438000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533524400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533610800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533697200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533783600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533870000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533956400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534042800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534129200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534215600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534302000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534388400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534474800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534561200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534647600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534734000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534820400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534906800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534993200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535079600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535166000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535252400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535338800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535425200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535511600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535598000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535684400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535770800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535857200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535943600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536030000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536116400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536202800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536289200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536375600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536462000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536548400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536634800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536721200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536807600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536894000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536980400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537066800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537153200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537239600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537326000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537412400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537498800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537585200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537671600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537758000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537844400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537930800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538017200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538103600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538190000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538276400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538362800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538449200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538535600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538622000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538708400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538794800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538881200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538967600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539054000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539140400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539226800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539313200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539399600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539486000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539572400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539658800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539745200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539831600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539918000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540004400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540090800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540177200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540263600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540350000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540436400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540522800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540609200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540695600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540782000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540868400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540954800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541041200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541127600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541214000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541300400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541386800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541473200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541559600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541646000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541732400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541818800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541905200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541991600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542078000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542164400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542250800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542337200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542423600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542510000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542596400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542682800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542769200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542855600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542942000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543028400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543114800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543201200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543287600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543374000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543460400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543546800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543633200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543719600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543806000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543892400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543978800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544065200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544151600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544238000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544324400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544410800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544497200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544583600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544670000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544756400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544842800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544929200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545015600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545102000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545188400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545274800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545361200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545447600, 'uvIndex': 0},
#   'daily': {'data': [{'time': 1545444000,
#      'sunriseTime': 1545448980,
#      'sunsetTime': 1545526380,
#      'moonPhase': 0.51,
#      'precipType': 'snow',
#      'temperatureLow': -3.66,
#      'temperatureLowTime': 1545524580,
#      'apparentTemperatureLow': -5.18,
#      'apparentTemperatureLowTime': 1545523500}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545534000,
#    'summary': 'Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0.0072,
#    'precipProbability': 0.04,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0086,
#    'temperature': -2.7,
#    'apparentTemperature': -2.7,
#    'dewPoint': -10.79,
#    'humidity': 0.54,
#    'pressure': 994.5,
#    'windSpeed': 3.83,
#    'windGust': 5.5,
#    'windBearing': 49,
#    'cloudCover': 0.37,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 301.4},
#   'daily': {'data': [{'time': 1545530400,
#      'summary': 'Partly cloudy throughout the day.',
#      'icon': 'partly-cloudy-day',
#      'sunriseTime': 1545535440,
#      'sunsetTime': 1545612780,
#      'moonPhase': 0.55,
#      'precipIntensity': 0.0039,
#      'precipIntensityMax': 0.0109,
#      'precipIntensityMaxTime': 1545610740,
#      'precipProbability': 0.09,
#      'precipType': 'snow',
#      'precipAccumulation': 0.1,
#      'temperatureHigh': 0.02,
#      'temperatureHighTime': 1545594600,
#      'temperatureLow': -3.45,
#      'temperatureLowTime': 1545621240,
#      'apparentTemperatureHigh': -1.14,
#      'apparentTemperatureHighTime': 1545555600,
#      'apparentTemperatureLow': -7.97,
#      'apparentTemperatureLowTime': 1545622080,
#      'dewPoint': -8.26,
#      'humidity': 0.58,
#      'pressure': 994.9,
#      'windSpeed': 8.61,
#      'windGust': 14,
#      'windGustTime': 1545605220,
#      'windBearing': 23,
#      'cloudCover': 0.57,
#      'uvIndex': 4,
#      'uvIndexTime': 1545575760,
#      'visibility': 16.093,
#      'ozone': 296.8,
#      'temperatureMin': -3.27,
#      'temperatureMinTime': 1545530400,
#      'temperatureMax': 0.02,
#      'temperatureMaxTime': 1545594600,
#      'apparentTemperatureMin': -7.12,
#      'apparentTemperatureMinTime': 1545613200,
#      'apparentTemperatureMax': -1.05,
#      'apparentTemperatureMaxTime': 1545554700}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545620400,
#    'summary': 'Clear',
#    'icon': 'clear-night',
#    'precipIntensity': 0.0056,
#    'precipProbability': 0.02,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0069,
#    'temperature': -3.17,
#    'apparentTemperature': -7.94,
#    'dewPoint': -11.31,
#    'humidity': 0.53,
#    'pressure': 994.8,
#    'windSpeed': 13.29,
#    'windGust': 14.02,
#    'windBearing': 11,
#    'cloudCover': 0.03,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 299.6},
#   'daily': {'data': [{'time': 1545616800,
#      'summary': 'Partly cloudy throughout the day.',
#      'icon': 'clear-day',
#      'sunriseTime': 1545621900,
#      'sunsetTime': 1545699180,
#      'moonPhase': 0.58,
#      'precipIntensity': 0.0162,
#      'precipIntensityMax': 0.0663,
#      'precipIntensityMaxTime': 1545699600,
#      'precipProbability': 0.17,
#      'precipType': 'snow',
#      'precipAccumulation': 0.2,
#      'temperatureHigh': 0.62,
#      'temperatureHighTime': 1545682560,
#      'temperatureLow': -1.32,
#      'temperatureLowTime': 1545706800,
#      'apparentTemperatureHigh': -5.61,
#      'apparentTemperatureHighTime': 1545663600,
#      'apparentTemperatureLow': -7.38,
#      'apparentTemperatureLowTime': 1545708300,
#      'dewPoint': -7.6,
#      'humidity': 0.61,
#      'pressure': 993.5,
#      'windSpeed': 21.38,
#      'windGust': 37.5,
#      'windGustTime': 1545699600,
#      'windBearing': 7,
#      'cloudCover': 0.29,
#      'uvIndex': 6,
#      'uvIndexTime': 1545661080,
#      'visibility': 16.093,
#      'ozone': 299.7,
#      'temperatureMin': -3.45,
#      'temperatureMinTime': 1545621240,
#      'temperatureMax': 0.62,
#      'temperatureMaxTime': 1545682560,
#      'apparentTemperatureMin': -7.97,
#      'apparentTemperatureMinTime': 1545622080,
#      'apparentTemperatureMax': -5.61,
#      'apparentTemperatureMaxTime': 1545663600}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545706800,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.072,
#    'precipProbability': 0.18,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0772,
#    'temperature': -1.05,
#    'apparentTemperature': -7.36,
#    'dewPoint': -7.2,
#    'humidity': 0.63,
#    'pressure': 986.8,
#    'windSpeed': 25.97,
#    'windGust': 39.01,
#    'windBearing': 23,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 303.2},
#   'daily': {'data': [{'time': 1545703200,
#      'summary': 'Foggy until afternoon, starting again overnight.',
#      'icon': 'snow',
#      'sunriseTime': 1545708360,
#      'sunsetTime': 1545785580,
#      'moonPhase': 0.62,
#      'precipIntensity': 0.1168,
#      'precipIntensityMax': 0.2562,
#      'precipIntensityMaxTime': 1545748800,
#      'precipProbability': 0.37,
#      'precipType': 'snow',
#      'precipAccumulation': 1.4,
#      'temperatureHigh': 0.98,
#      'temperatureHighTime': 1545754800,
#      'temperatureLow': -1.42,
#      'temperatureLowTime': 1545794040,
#      'apparentTemperatureHigh': -5.44,
#      'apparentTemperatureHighTime': 1545771060,
#      'apparentTemperatureLow': -7.41,
#      'apparentTemperatureLowTime': 1545791520,
#      'dewPoint': -5.11,
#      'humidity': 0.69,
#      'pressure': 979.3,
#      'windSpeed': 31.16,
#      'windGust': 50.13,
#      'windGustTime': 1545739980,
#      'windBearing': 47,
#      'cloudCover': 0.99,
#      'uvIndex': 4,
#      'uvIndexTime': 1545746520,
#      'visibility': 12.149,
#      'ozone': 308.4,
#      'temperatureMin': -1.32,
#      'temperatureMinTime': 1545706800,
#      'temperatureMax': 0.98,
#      'temperatureMaxTime': 1545754800,
#      'apparentTemperatureMin': -7.38,
#      'apparentTemperatureMinTime': 1545708300,
#      'apparentTemperatureMax': -5.44,
#      'apparentTemperatureMaxTime': 1545771060}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545793200,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.1503,
#    'precipProbability': 0.18,
#    'precipType': 'snow',
#    'precipAccumulation': 0.1623,
#    'temperature': -1.15,
#    'apparentTemperature': -7.39,
#    'dewPoint': -7.07,
#    'humidity': 0.64,
#    'pressure': 973.7,
#    'windSpeed': 25.22,
#    'windGust': 36.02,
#    'windBearing': 77,
#    'cloudCover': 0.98,
#    'uvIndex': 0,
#    'visibility': 4.042,
#    'ozone': 315.7},
#   'daily': {'data': [{'time': 1545789600,
#      'summary': 'Foggy in the morning.',
#      'icon': 'snow',
#      'sunriseTime': 1545794880,
#      'sunsetTime': 1545871980,
#      'moonPhase': 0.66,
#      'precipIntensity': 0.0894,
#      'precipIntensityMax': 0.1695,
#      'precipIntensityMaxTime': 1545803400,
#      'precipProbability': 0.37,
#      'precipType': 'snow',
#      'precipAccumulation': 1.3,
#      'temperatureHigh': 0.81,
#      'temperatureHighTime': 1545836040,
#      'temperatureLow': -1.6,
#      'temperatureLowTime': 1545890100,
#      'apparentTemperatureHigh': -5.24,
#      'apparentTemperatureHighTime': 1545835200,
#      'apparentTemperatureLow': -7.59,
#      'apparentTemperatureLowTime': 1545880020,
#      'dewPoint': -4.87,
#      'humidity': 0.71,
#      'pressure': 973,
#      'windSpeed': 25.08,
#      'windGust': 37.5,
#      'windGustTime': 1545867480,
#      'windBearing': 101,
#      'cloudCover': 0.99,
#      'uvIndex': 4,
#      'uvIndexTime': 1545833340,
#      'visibility': 6.076,
#      'ozone': 313.5,
#      'temperatureMin': -1.42,
#      'temperatureMinTime': 1545794040,
#      'temperatureMax': 0.81,
#      'temperatureMaxTime': 1545836040,
#      'apparentTemperatureMin': -7.41,
#      'apparentTemperatureMinTime': 1545791520,
#      'apparentTemperatureMax': -5.24,
#      'apparentTemperatureMaxTime': 1545835200}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545879600,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0257,
#    'precipProbability': 0.11,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0281,
#    'temperature': -1.31,
#    'apparentTemperature': -7.59,
#    'dewPoint': -7.24,
#    'humidity': 0.64,
#    'pressure': 976.6,
#    'windSpeed': 25.12,
#    'windGust': 36.86,
#    'windBearing': 134,
#    'cloudCover': 0.95,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 314.2},
#   'daily': {'data': [{'time': 1545876000,
#      'summary': 'Overcast throughout the day.',
#      'icon': 'snow',
#      'sunriseTime': 1545881340,
#      'sunsetTime': 1545958320,
#      'moonPhase': 0.7,
#      'precipIntensity': 0.0285,
#      'precipIntensityMax': 0.0678,
#      'precipIntensityMaxTime': 1545944940,
#      'precipProbability': 0.25,
#      'precipType': 'snow',
#      'precipAccumulation': 0.5,
#      'temperatureHigh': 0.36,
#      'temperatureHighTime': 1545921300,
#      'temperatureLow': -2.76,
#      'temperatureLowTime': 1545974340,
#      'apparentTemperatureHigh': -5.46,
#      'apparentTemperatureHighTime': 1545940560,
#      'apparentTemperatureLow': -7.22,
#      'apparentTemperatureLowTime': 1545983820,
#      'dewPoint': -5.99,
#      'humidity': 0.67,
#      'pressure': 981.7,
#      'windSpeed': 22.77,
#      'windGust': 37.17,
#      'windGustTime': 1545876000,
#      'windBearing': 152,
#      'cloudCover': 0.94,
#      'uvIndex': 4,
#      'uvIndexTime': 1545920400,
#      'visibility': 14.57,
#      'ozone': 308.7,
#      'temperatureMin': -1.89,
#      'temperatureMinTime': 1545958800,
#      'temperatureMax': 0.36,
#      'temperatureMaxTime': 1545921300,
#      'apparentTemperatureMin': -7.59,
#      'apparentTemperatureMinTime': 1545880020,
#      'apparentTemperatureMax': -5.46,
#      'apparentTemperatureMaxTime': 1545940560}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1545966000,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0174,
#    'precipProbability': 0.09,
#    'precipType': 'snow',
#    'precipAccumulation': 0.02,
#    'temperature': -2.11,
#    'apparentTemperature': -6.88,
#    'dewPoint': -8.95,
#    'humidity': 0.59,
#    'pressure': 987.3,
#    'windSpeed': 14.43,
#    'windGust': 17.79,
#    'windBearing': 173,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 314.1},
#   'daily': {'data': [{'time': 1545962400,
#      'summary': 'Partly cloudy throughout the day.',
#      'icon': 'partly-cloudy-day',
#      'sunriseTime': 1545967860,
#      'sunsetTime': 1546044660,
#      'moonPhase': 0.73,
#      'precipIntensity': 0.0083,
#      'precipIntensityMax': 0.022,
#      'precipIntensityMaxTime': 1545983400,
#      'precipProbability': 0.16,
#      'precipType': 'snow',
#      'precipAccumulation': 0.2,
#      'temperatureHigh': -0.36,
#      'temperatureHighTime': 1546013580,
#      'temperatureLow': -3.83,
#      'temperatureLowTime': 1546059480,
#      'apparentTemperatureHigh': -5.98,
#      'apparentTemperatureHighTime': 1546028100,
#      'apparentTemperatureLow': -8.07,
#      'apparentTemperatureLowTime': 1546052640,
#      'dewPoint': -8.56,
#      'humidity': 0.59,
#      'pressure': 989.9,
#      'windSpeed': 16.6,
#      'windGust': 21.24,
#      'windGustTime': 1546015260,
#      'windBearing': 193,
#      'cloudCover': 0.46,
#      'uvIndex': 6,
#      'uvIndexTime': 1546008660,
#      'visibility': 16.093,
#      'ozone': 311.9,
#      'temperatureMin': -3.58,
#      'temperatureMinTime': 1546045200,
#      'temperatureMax': -0.36,
#      'temperatureMaxTime': 1546013580,
#      'apparentTemperatureMin': -8.02,
#      'apparentTemperatureMinTime': 1546045200,
#      'apparentTemperatureMax': -5.98,
#      'apparentTemperatureMaxTime': 1546028100}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1546052400,
#    'summary': 'Clear',
#    'icon': 'clear-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': -3.41,
#    'apparentTemperature': -8.07,
#    'dewPoint': -11.01,
#    'humidity': 0.56,
#    'pressure': 993.2,
#    'windSpeed': 12.64,
#    'windGust': 13.27,
#    'windBearing': 218,
#    'cloudCover': 0.25,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 313.4},
#   'daily': {'data': [{'time': 1546048800,
#      'summary': 'Clear throughout the day.',
#      'icon': 'clear-day',
#      'sunriseTime': 1546054380,
#      'sunsetTime': 1546131000,
#      'moonPhase': 0.77,
#      'precipIntensity': 0.006,
#      'precipIntensityMax': 0.0162,
#      'precipIntensityMaxTime': 1546116600,
#      'precipProbability': 0.11,
#      'precipType': 'snow',
#      'precipAccumulation': 0.1,
#      'temperatureHigh': -0.19,
#      'temperatureHighTime': 1546113240,
#      'temperatureLow': -3.34,
#      'temperatureLowTime': 1546147560,
#      'apparentTemperatureHigh': -5.83,
#      'apparentTemperatureHighTime': 1546113060,
#      'apparentTemperatureLow': -7.94,
#      'apparentTemperatureLowTime': 1546129140,
#      'dewPoint': -8.58,
#      'humidity': 0.6,
#      'pressure': 995.8,
#      'windSpeed': 16.52,
#      'windGust': 25.3,
# ...
#      'apparentTemperatureHigh': -10.06,
#      'apparentTemperatureHighTime': 1587549720,
#      'apparentTemperatureLow': -12.71,
#      'apparentTemperatureLowTime': 1587603720,
#      'dewPoint': -19.54,
#      'humidity': 0.33,
#      'pressure': 976,
#      'windSpeed': 15.05,
#      'windGust': 30.68,
#      'windGustTime': 1587602940,
#      'windBearing': 187,
#      'cloudCover': 1,
#      'uvIndex': 0,
#      'uvIndexTime': 1587564300,
#      'visibility': 14.752,
#      'ozone': 282.7,
#      'temperatureMin': -6.89,
#      'temperatureMinTime': 1587539580,
#      'temperatureMax': -4.28,
#      'temperatureMaxTime': 1587579720,
#      'apparentTemperatureMin': -12.71,
#      'apparentTemperatureMinTime': 1587603600,
#      'apparentTemperatureMax': -10.06,
#      'apparentTemperatureMaxTime': 1587549720}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1587610800,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0336,
#    'precipProbability': 0.04,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0446,
#    'temperature': -4.23,
#    'apparentTemperature': -11.44,
#    'dewPoint': -16.49,
#    'humidity': 0.38,
#    'pressure': 977.1,
#    'windSpeed': 25.82,
#    'windGust': 29.8,
#    'windBearing': 158,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 11.787,
#    'ozone': 299.8},
#   'daily': {'data': [{'time': 1587607200,
#      'summary': 'Windy overnight.',
#      'icon': 'cloudy',
#      'sunriseTime': 1587635580,
#      'sunsetTime': 1587666120,
#      'moonPhase': 0.03,
#      'precipIntensity': 0.0265,
#      'precipIntensityMax': 0.0506,
#      'precipIntensityMaxTime': 1587685680,
#      'precipProbability': 0.22,
#      'precipType': 'snow',
#      'precipAccumulation': 0.7,
#      'temperatureHigh': -3.85,
#      'temperatureHighTime': 1587664680,
#      'temperatureLow': -5.86,
#      'temperatureLowTime': 1587717540,
#      'apparentTemperatureHigh': -11.82,
#      'apparentTemperatureHighTime': 1587632400,
#      'apparentTemperatureLow': -15.44,
#      'apparentTemperatureLowTime': 1587717780,
#      'dewPoint': -14.79,
#      'humidity': 0.44,
#      'pressure': 981.1,
#      'windSpeed': 30.97,
#      'windGust': 44.28,
#      'windGustTime': 1587690000,
#      'windBearing': 166,
#      'cloudCover': 1,
#      'uvIndex': 0,
#      'uvIndexTime': 1587650700,
#      'visibility': 7.054,
#      'ozone': 311.3,
#      'temperatureMin': -5.66,
#      'temperatureMinTime': 1587690000,
#      'temperatureMax': -3.64,
#      'temperatureMaxTime': 1587621420,
#      'apparentTemperatureMin': -14.6,
#      'apparentTemperatureMinTime': 1587690000,
#      'apparentTemperatureMax': -11.34,
#      'apparentTemperatureMaxTime': 1587613740}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1587697200,
#    'summary': 'Windy and Overcast',
#    'icon': 'wind',
#    'precipIntensity': 0.0573,
#    'precipProbability': 0.04,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0813,
#    'temperature': -5.23,
#    'apparentTemperature': -14.46,
#    'dewPoint': -17.53,
#    'humidity': 0.37,
#    'pressure': 985.6,
#    'windSpeed': 40.99,
#    'windGust': 45.32,
#    'windBearing': 178,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 4.429,
#    'ozone': 322},
#   'daily': {'data': [{'time': 1587693600,
#      'summary': 'Windy until evening.',
#      'icon': 'snow',
#      'sunriseTime': 1587722160,
#      'sunsetTime': 1587752340,
#      'moonPhase': 0.06,
#      'precipIntensity': 0.0444,
#      'precipIntensityMax': 0.0701,
#      'precipIntensityMaxTime': 1587723960,
#      'precipProbability': 0.27,
#      'precipType': 'snow',
#      'precipAccumulation': 1.4,
#      'temperatureHigh': -4.4,
#      'temperatureHighTime': 1587729720,
#      'temperatureLow': -9.35,
#      'temperatureLowTime': 1587808800,
#      'apparentTemperatureHigh': -14.17,
#      'apparentTemperatureHighTime': 1587729600,
#      'apparentTemperatureLow': -18.56,
#      'apparentTemperatureLowTime': 1587808800,
#      'dewPoint': -16.08,
#      'humidity': 0.44,
#      'pressure': 987.6,
#      'windSpeed': 45.03,
#      'windGust': 53.54,
#      'windGustTime': 1587739860,
#      'windBearing': 193,
#      'cloudCover': 1,
#      'uvIndex': 0,
#      'uvIndexTime': 1587737100,
#      'visibility': 2.674,
#      'ozone': 320.2,
#      'temperatureMin': -7.08,
#      'temperatureMinTime': 1587768960,
#      'temperatureMax': -4.4,
#      'temperatureMaxTime': 1587729720,
#      'apparentTemperatureMin': -16.84,
#      'apparentTemperatureMinTime': 1587768840,
#      'apparentTemperatureMax': -14.17,
#      'apparentTemperatureMaxTime': 1587729600}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1587783600,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0622,
#    'precipProbability': 0.11,
#    'precipType': 'snow',
#    'precipAccumulation': 0.099,
#    'temperature': -6.93,
#    'apparentTemperature': -16.04,
#    'dewPoint': -19.98,
#    'humidity': 0.35,
#    'pressure': 987.6,
#    'windSpeed': 34.46,
#    'windGust': 36.51,
#    'windBearing': 214,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 3.484,
#    'ozone': 312.6},
#   'daily': {'data': [{'time': 1587780000,
#      'summary': 'Foggy in the morning and afternoon.',
#      'icon': 'snow',
#      'sunriseTime': 1587808740,
#      'sunsetTime': 1587838560,
#      'moonPhase': 0.09,
#      'precipIntensity': 0.0606,
#      'precipIntensityMax': 0.1507,
#      'precipIntensityMaxTime': 1587805440,
#      'precipProbability': 0.42,
#      'precipType': 'snow',
#      'precipAccumulation': 2.6,
#      'temperatureHigh': -8.1,
#      'temperatureHighTime': 1587805200,
#      'temperatureLow': -10.41,
#      'temperatureLowTime': 1587848400,
#      'apparentTemperatureHigh': -17.68,
#      'apparentTemperatureHighTime': 1587805200,
#      'apparentTemperatureLow': -17.97,
#      'apparentTemperatureLowTime': 1587848400,
#      'dewPoint': -22.33,
#      'humidity': 0.35,
#      'pressure': 980.9,
#      'windSpeed': 28.73,
#      'windGust': 39.99,
#      'windGustTime': 1587780000,
#      'windBearing': 225,
#      'cloudCover': 1,
#      'uvIndex': 0,
#      'uvIndexTime': 1587823320,
#      'visibility': 4.586,
#      'ozone': 309.9,
#      'temperatureMin': -11.52,
#      'temperatureMinTime': 1587828060,
#      'temperatureMax': -6.49,
#      'temperatureMaxTime': 1587780000,
#      'apparentTemperatureMin': -20.96,
#      'apparentTemperatureMinTime': 1587829440,
#      'apparentTemperatureMax': -16.04,
#      'apparentTemperatureMaxTime': 1587783360}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1587870000,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0198,
#    'precipProbability': 0.04,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0373,
#    'temperature': -9.46,
#    'apparentTemperature': -16.04,
#    'dewPoint': -27.19,
#    'humidity': 0.22,
#    'pressure': 974.9,
#    'windSpeed': 14.93,
#    'windGust': 16.72,
#    'windBearing': 190,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 8.51,
#    'ozone': 308.7},
#   'daily': {'data': [{'time': 1587866400,
#      'summary': 'Foggy in the morning and overnight.',
#      'icon': 'snow',
#      'sunriseTime': 1587895320,
#      'sunsetTime': 1587924720,
#      'moonPhase': 0.12,
#      'precipIntensity': 0.0288,
#      'precipIntensityMax': 0.0783,
#      'precipIntensityMaxTime': 1587893640,
#      'precipProbability': 0.34,
#      'precipType': 'snow',
#      'precipAccumulation': 1.2,
#      'temperatureHigh': -7.46,
#      'temperatureHighTime': 1587915420,
#      'temperatureLow': -9.14,
#      'temperatureLowTime': 1587949920,
#      'apparentTemperatureHigh': -16.47,
#      'apparentTemperatureHighTime': 1587914640,
#      'apparentTemperatureLow': -17.54,
#      'apparentTemperatureLowTime': 1587949500,
#      'dewPoint': -21.27,
#      'humidity': 0.35,
#      'pressure': 972.5,
#      'windSpeed': 24.7,
#      'windGust': 30.14,
#      'windGustTime': 1587895740,
#      'windBearing': 222,
#      'cloudCover': 1,
#      'uvIndex': 0,
#      'uvIndexTime': 1587909840,
#      'visibility': 8.601,
#      'ozone': 305.9,
#      'temperatureMin': -9.9,
#      'temperatureMinTime': 1587866400,
#      'temperatureMax': -7.46,
#      'temperatureMaxTime': 1587915420,
#      'apparentTemperatureMin': -17.53,
#      'apparentTemperatureMinTime': 1587949200,
#      'apparentTemperatureMax': -14.43,
#      'apparentTemperatureMaxTime': 1587879660}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1587956400,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0272,
#    'precipProbability': 0.09,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0479,
#    'temperature': -8.44,
#    'apparentTemperature': -16.71,
#    'dewPoint': -22.53,
#    'humidity': 0.31,
#    'pressure': 972.6,
#    'windSpeed': 24.82,
#    'windGust': 24.82,
#    'windBearing': 207,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 3.742,
#    'ozone': 318.1},
#   'daily': {'data': [{'time': 1587952800,
#      'summary': 'Foggy throughout the day.',
#      'icon': 'snow',
#      'sunriseTime': 1587981900,
#      'sunsetTime': 1588010940,
#      'moonPhase': 0.15,
#      'precipIntensity': 0.0299,
#      'precipIntensityMax': 0.0632,
#      'precipIntensityMaxTime': 1588009440,
#      'precipProbability': 0.29,
#      'precipType': 'snow',
#      'precipAccumulation': 1.1,
#      'temperatureHigh': -5.81,
#      'temperatureHighTime': 1587987360,
#      'temperatureLow': -8.56,
#      'temperatureLowTime': 1588051200,
#      'apparentTemperatureHigh': -14.17,
#      'apparentTemperatureHighTime': 1587987120,
#      'apparentTemperatureLow': -18.42,
#      'apparentTemperatureLowTime': 1588051800,
#      'dewPoint': -17.92,
#      'humidity': 0.43,
#      'pressure': 976.7,
#      'windSpeed': 28.55,
#      'windGust': 35.64,
#      'windGustTime': 1588035600,
#      'windBearing': 208,
#      'cloudCover': 1,
#      'uvIndex': 0,
#      'uvIndexTime': 1587996300,
#      'visibility': 2.38,
#      'ozone': 304.7,
#      'temperatureMin': -8.99,
#      'temperatureMinTime': 1587952800,
#      'temperatureMax': -5.81,
#      'temperatureMaxTime': 1587987360,
#      'apparentTemperatureMin': -17.18,
#      'apparentTemperatureMinTime': 1587952800,
#      'apparentTemperatureMax': -14.17,
#      'apparentTemperatureMaxTime': 1587987120}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1588042800,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0494,
#    'precipProbability': 0.06,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0844,
#    'temperature': -8,
#    'apparentTemperature': -17.99,
#    'dewPoint': -19.19,
#    'humidity': 0.4,
#    'pressure': 977,
#    'windSpeed': 39.24,
#    'windGust': 40.88,
#    'windBearing': 213,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 1.394,
#    'ozone': 293.9},
#   'daily': {'data': [{'time': 1588039200,
#      'summary': 'Windy and foggy throughout the day.',
#      'icon': 'snow',
#      'sunriseTime': 1588068480,
#      'sunsetTime': 1588097160,
#      'moonPhase': 0.19,
#      'precipIntensity': 0.1059,
#      'precipIntensityMax': 0.2617,
#      'precipIntensityMaxTime': 1588097400,
#      'precipProbability': 0.44,
#      'precipType': 'snow',
#      'precipAccumulation': 3.6,
#      'temperatureHigh': -5.26,
#      'temperatureHighTime': 1588089540,
#      'temperatureLow': -7.57,
#      'temperatureLowTime': 1588135980,
#      'apparentTemperatureHigh': -15.78,
#      'apparentTemperatureHighTime': 1588088700,
#      'apparentTemperatureLow': -19.17,
#      'apparentTemperatureLowTime': 1588136040,
#      'dewPoint': -15.6,
#      'humidity': 0.49,
#      'pressure': 975.1,
#      'windSpeed': 48.03,
#      'windGust': 66.76,
#      'windGustTime': 1588122000,
#      'windBearing': 211,
#      'cloudCover': 1,
#      'uvIndex': 0,
#      'uvIndexTime': 1588082580,
#      'visibility': 0.729,
#      'ozone': 309.6,
#      'temperatureMin': -8.56,
#      'temperatureMinTime': 1588051200,
#      'temperatureMax': -3.39,
#      'temperatureMaxTime': 1588119360,
#      'apparentTemperatureMin': -18.42,
#      'apparentTemperatureMinTime': 1588051800,
#      'apparentTemperatureMax': -13.54,
#      'apparentTemperatureMaxTime': 1588119360}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1588129200,
#    'summary': 'Windy and Overcast',
#    'icon': 'wind',
#    'precipIntensity': 0.1116,
#    'precipProbability': 0.11,
#    'precipType': 'snow',
#    'precipAccumulation': 0.1786,
#    'temperature': -7.02,
#    'apparentTemperature': -18.62,
#    'dewPoint': -17.24,
#    'humidity': 0.44,
#    'pressure': 975.6,
#    'windSpeed': 62.18,
#    'windGust': 70.19,
#    'windBearing': 204,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 0.383,
#    'ozone': 316.7},
#   'daily': {'data': [{'time': 1588125600,
#      'summary': 'Dangerously windy until evening.',
#      'icon': 'snow',
#      'sunriseTime': 1588155060,
#      'sunsetTime': 1588183320,
#      'moonPhase': 0.22,
#      'precipIntensity': 0.0636,
#      'precipIntensityMax': 0.1173,
#      'precipIntensityMaxTime': 1588131540,
#      'precipProbability': 0.51,
#      'precipType': 'snow',
#      'precipAccumulation': 1.9,
#      'temperatureHigh': -2.5,
#      'temperatureHighTime': 1588173360,
#      'temperatureLow': -6.23,
#      'temperatureLowTime': 1588236360,
#      'apparentTemperatureHigh': -12.53,
#      'apparentTemperatureHighTime': 1588173600,
#      'apparentTemperatureLow': -14.52,
#      'apparentTemperatureLowTime': 1588232460,
#      'dewPoint': -13.29,
#      'humidity': 0.51,
#      'pressure': 986.9,
#      'windSpeed': 59.11,
#      'windGust': 76.72,
#      'windGustTime': 1588153800,
#      'windBearing': 200,
#      'cloudCover': 1,
#      'uvIndex': 0,
#      'uvIndexTime': 1588169040,
#      'visibility': 0.751,
#      'ozone': 308.4,
#      'temperatureMin': -7.57,
#      'temperatureMinTime': 1588135980,
#      'temperatureMax': -2.5,
#      'temperatureMaxTime': 1588173360,
#      'apparentTemperatureMin': -19.17,
#      'apparentTemperatureMinTime': 1588136040,
#      'apparentTemperatureMax': -12.53,
#      'apparentTemperatureMaxTime': 1588173600}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1588215600,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0272,
#    'precipProbability': 0.02,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0368,
#    'temperature': -4.53,
#    'apparentTemperature': -13.31,
#    'dewPoint': -16.11,
#    'humidity': 0.4,
#    'pressure': 1001.6,
#    'windSpeed': 38.75,
#    'windGust': 41.3,
#    'windBearing': 204,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 3.62,
#    'ozone': 276.1},
#   'daily': {'data': [{'time': 1588212000,
#      'summary': 'Possible light snow (1–2 cm.) overnight.',
#      'icon': 'snow',
#      'sunriseTime': 1588241640,
#      'sunsetTime': 1588269540,
#      'moonPhase': 0.25,
#      'precipIntensity': 0.0441,
#      'precipIntensityMax': 0.2529,
#      'precipIntensityMaxTime': 1588293240,
#      'precipProbability': 0.35,
#      'precipType': 'snow',
#      'precipAccumulation': 0.8,
#      'temperatureHigh': -0.8,
#      'temperatureHighTime': 1588280400,
#      'temperatureLow': -1.35,
#      'temperatureLowTime': 1588280400,
#      'apparentTemperatureHigh': -9.05,
#      'apparentTemperatureHighTime': 1588280400,
#      'apparentTemperatureLow': -9.05,
#      'apparentTemperatureLowTime': 1588280400,
#      'dewPoint': -13.53,
#      'humidity': 0.47,
#      'pressure': 998.8,
#      'windSpeed': 35.52,
#      'windGust': 63.99,
#      'windGustTime': 1588288860,
#      'windBearing': 271,
#      'cloudCover': 0.99,
#      'uvIndex': 0,
#      'uvIndexTime': 1588255440,
#      'visibility': 10.431,
#      'ozone': 252.5,
#      'temperatureMin': -6.23,
#      'temperatureMinTime': 1588236360,
#      'temperatureMax': 0.22,
#      'temperatureMaxTime': 1588294800,
#      'apparentTemperatureMin': -14.52,
#      'apparentTemperatureMinTime': 1588232460,
#      'apparentTemperatureMax': -7.69,
#      'apparentTemperatureMaxTime': 1588294800}]},
#   'offset': -2}]

# %%
flatten_json = pd.json_normalize(data) # esta linea en teoria devuelve el json desanidado
flatten_json # pero como se ve toda la data anidada en la llave daily queda comprimida en daily.data.
# Out:
#       latitude  longitude   timezone  offset  currently.time  \
# 0   -64.533333 -32.066667  Etc/GMT+2      -2      1525143600
# 1   -64.533333 -32.066667  Etc/GMT+2      -2      1525230000
# 2   -64.533333 -32.066667  Etc/GMT+2      -2      1525316400
# 3   -64.533333 -32.066667  Etc/GMT+2      -2      1525402800
# 4   -64.533333 -32.066667  Etc/GMT+2      -2      1525489200
# ..         ...        ...        ...     ...             ...
# 726 -64.533333 -32.066667  Etc/GMT+2      -2      1587870000
# 727 -64.533333 -32.066667  Etc/GMT+2      -2      1587956400
# 728 -64.533333 -32.066667  Etc/GMT+2      -2      1588042800
# 729 -64.533333 -32.066667  Etc/GMT+2      -2      1588129200
# 730 -64.533333 -32.066667  Etc/GMT+2      -2      1588215600
#
#      currently.uvIndex                                         daily.data  \
# 0                    0                                                NaN
# 1                    0                                                NaN
# 2                    0                                                NaN
# 3                    0                                                NaN
# 4                    0                                                NaN
# ..                 ...                                                ...
# 726                  0  [{'time': 1587866400, 'summary': 'Foggy in the...
# 727                  0  [{'time': 1587952800, 'summary': 'Foggy throug...
# 728                  0  [{'time': 1588039200, 'summary': 'Windy and fo...
# 729                  0  [{'time': 1588125600, 'summary': 'Dangerously ...
# 730                  0  [{'time': 1588212000, 'summary': 'Possible lig...
#
#       currently.summary currently.icon  currently.precipIntensity  ...  \
# 0                   NaN            NaN                        NaN  ...
# 1                   NaN            NaN                        NaN  ...
# 2                   NaN            NaN                        NaN  ...
# 3                   NaN            NaN                        NaN  ...
# 4                   NaN            NaN                        NaN  ...
# ..                  ...            ...                        ...  ...
# 726            Overcast         cloudy                     0.0198  ...
# 727            Overcast         cloudy                     0.0272  ...
# 728            Overcast         cloudy                     0.0494  ...
# 729  Windy and Overcast           wind                     0.1116  ...
# 730            Overcast         cloudy                     0.0272  ...
#
#      currently.apparentTemperature currently.dewPoint  currently.humidity  \
# 0                              NaN                NaN                 NaN
# 1                              NaN                NaN                 NaN
# 2                              NaN                NaN                 NaN
# 3                              NaN                NaN                 NaN
# 4                              NaN                NaN                 NaN
# ..                             ...                ...                 ...
# 726                         -16.04             -27.19                0.22
# 727                         -16.71             -22.53                0.31
# 728                         -17.99             -19.19                0.40
# 729                         -18.62             -17.24                0.44
# 730                         -13.31             -16.11                0.40
#
#      currently.pressure  currently.windSpeed  currently.windGust  \
# 0                   NaN                  NaN                 NaN
# 1                   NaN                  NaN                 NaN
# 2                   NaN                  NaN                 NaN
# 3                   NaN                  NaN                 NaN
# 4                   NaN                  NaN                 NaN
# ..                  ...                  ...                 ...
# 726               974.9                14.93               16.72
# 727               972.6                24.82               24.82
# 728               977.0                39.24               40.88
# 729               975.6                62.18               70.19
# 730              1001.6                38.75               41.30
#
#      currently.windBearing  currently.cloudCover  currently.visibility  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ..                     ...                   ...                   ...
# 726                  190.0                   1.0                 8.510
# 727                  207.0                   1.0                 3.742
# 728                  213.0                   1.0                 1.394
# 729                  204.0                   1.0                 0.383
# 730                  204.0                   1.0                 3.620
#
#      currently.ozone
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 726            308.7
# 727            318.1
# 728            293.9
# 729            316.7
# 730            276.1
#
# [731 rows x 24 columns]

# %%
# identificar a partir de que fecha hay informacion, y luego descartar la informacion vacia

for n,dat in enumerate(data):
    try:
        if data[n]['daily']:
            print(n)
        break
    except KeyError:
        continue
# Out:
# 235

# %%
cleaned_json = data[236::]
flatten_json = pd.json_normalize(cleaned_json, ['daily', 'data'])
flatten_json.columns
# Out:
# Index(['time', 'summary', 'icon', 'sunriseTime', 'sunsetTime', 'moonPhase',
#        'precipIntensity', 'precipIntensityMax', 'precipIntensityMaxTime',
#        'precipProbability', 'precipType', 'precipAccumulation',
#        'temperatureHigh', 'temperatureHighTime', 'temperatureLow',
#        'temperatureLowTime', 'apparentTemperatureHigh',
#        'apparentTemperatureHighTime', 'apparentTemperatureLow',
#        'apparentTemperatureLowTime', 'dewPoint', 'humidity', 'pressure',
#        'windSpeed', 'windGust', 'windGustTime', 'windBearing', 'cloudCover',
#        'uvIndex', 'uvIndexTime', 'visibility', 'ozone', 'temperatureMin',
#        'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime',
#        'apparentTemperatureMin', 'apparentTemperatureMinTime',
#        'apparentTemperatureMax', 'apparentTemperatureMaxTime'],
#       dtype='object')

# %%
df = flatten_json[['time',
                   'summary',
                   'precipAccumulation',
                   'humidity',
                   'pressure',
                   'windSpeed',
                   'uvIndex',
                   'temperatureMin',
                   'temperatureMax']]

# %%
df['time'] = df['time'].apply(lambda x: datetime.datetime.fromtimestamp(x))
# Out:
# /home/horacio/anaconda3/envs/diplo/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.set_index('time').head()
# Out:
#                                                               summary  \
# time
# 2018-12-22 23:00:00                 Partly cloudy throughout the day.
# 2018-12-23 23:00:00                 Partly cloudy throughout the day.
# 2018-12-24 23:00:00  Foggy until afternoon, starting again overnight.
# 2018-12-25 23:00:00                             Foggy in the morning.
# 2018-12-26 23:00:00                      Overcast throughout the day.
#
#                      precipAccumulation  humidity  pressure  windSpeed  \
# time
# 2018-12-22 23:00:00                 0.1      0.58     994.9       8.61
# 2018-12-23 23:00:00                 0.2      0.61     993.5      21.38
# 2018-12-24 23:00:00                 1.4      0.69     979.3      31.16
# 2018-12-25 23:00:00                 1.3      0.71     973.0      25.08
# 2018-12-26 23:00:00                 0.5      0.67     981.7      22.77
#
#                      uvIndex  temperatureMin  temperatureMax
# time
# 2018-12-22 23:00:00        4           -3.27            0.02
# 2018-12-23 23:00:00        6           -3.45            0.62
# 2018-12-24 23:00:00        4           -1.32            0.98
# 2018-12-25 23:00:00        4           -1.42            0.81
# 2018-12-26 23:00:00        4           -1.89            0.36

# %%
df.to_csv('scrapped_sta_rosa_dark_sky.csv',index=False)

# %% [markdown]
# ## 2. Análisis y curación de datos Scrapeados de WeatherUnderground
#
# Referencias: https://www.wunderground.com/
#
#   1. Extraer los datos para la estación meteorológica personal (PWS, por siglas en inglés) "ICALAMUC5" (en Villa General Belgrano), para el período 1/Mayo/2018 al 01/Mayo/2020 mediante el Scrappeo de WeatherUnderground (WU).
#   2. ¿Existen valores faltantes? Cuantificarlos.
#   3. Convertir los datos faltantes en NaN.
#   4. Hacer las conversiones de unidades necesarias a estos datos para poder compararlos con "APRHi - Sta Rosa de Calamuchita".
#   5. Comparar los estadísticos de este dataset con los de "APRHi - Sta Rosa de Calamuchita".

# %%
#!pip3 install requests bs4

# %%
from bs4 import BeautifulSoup as bs
import requests
from urllib.request import urlopen
import datetime
import pandas as pd

# %%
stations = ["ICALAMUC3"]
start_date = datetime.date(2018, 5, 1)
end_date = datetime.date(2020, 5, 6) #Esta fecha no es incluida
rango = 'daily'
baseUrl = 'https://www.wunderground.com/dashboard/pws/<station>/table/<date>/<date>/daily'

# %%
# stations_temp = []

for station in stations:
    print(station)
    tab_exist = 0
    for date in daterange(start_date, end_date):
        url = baseUrl.replace("<date>", date.strftime("%Y-%m-%d")).replace("<station>", station)
        page = bs(requests.get(url).content)
        response = requests.get(url)
        tabla = page.find('table', attrs={'class':'history-table desktop-table'})
        if tab_exist == 0:
            if tabla:
                print('Hay datos', date, station)
                tab_exist = 1
                #Creo lista con el nombre de las columnas
                list_html = tabla.find_all('th')
                #lista con las unidades
                list_unid = ['','C','C','%','','km/h','km/h','hPa','mm','mm','','']
                list_col = []
                for i in list_html:
                    col_temp = i.string
                    list_col.append(col_temp)
                for j in range(len(list_col)):
                    if list_unid[j]:          
                        list_col[j] = list_col[j] + '[' + list_unid[j] + ']'
                        #list_col[j] = list_col[j].strip('()'
                df_wu = pd.DataFrame(columns = list_col)
                tab_exist=1
        if tab_exist == 1:    #Entra acá cuando ya se creo la lista con los parametros
            print(date)
            if response.status_code == 200:
                if tabla:
                    m = tabla.tbody.find_all('tr')
                    m_val = []
                    for i in m:
                        list_temp = []
                        l_html = i.find_all('td')
                        for j in range(0,len(l_html)): 
                            if j == 0:
                                list_temp.append(date.strftime("%Y-%m-%d") +' '+ l_html[j].string)
                            elif j == 4 or j == 10 or j == 11: 
                                list_temp.append(l_html[j].string) 
                            else:
                                list_temp.append(l_html[j].span.span.string)
                        m_val.append(list_temp) # Matriz con los valores
                    df_temp = pd.DataFrame(m_val, columns=list_col)  # Transformo la matriz en un DataFrame
                    df_temp['Station'] = station
                    df_temp['Date'] = date
                    df_wu = pd.concat([df_wu,df_temp], axis=0)
            else:
                print(response)
# Out:
# ICALAMUC3
# Hay datos 2018-05-01 ICALAMUC3
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-05
# 2018-05-06
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-12
# 2018-05-13
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-19
# 2018-05-20
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-26
# 2018-05-27
# 2018-05-28
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-02
# 2018-06-03
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-09
# 2018-06-10
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-16
# 2018-06-17
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-23
# 2018-06-24
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-06-30
# 2018-07-01
# 2018-07-02
# 2018-07-03
# 2018-07-04
# 2018-07-05
# 2018-07-06
# 2018-07-07
# 2018-07-08
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-14
# 2018-07-15
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-21
# 2018-07-22
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-28
# 2018-07-29
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-04
# 2018-08-05
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-11
# 2018-08-12
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-18
# 2018-08-19
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-25
# 2018-08-26
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-01
# 2018-09-02
# 2018-09-03
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-08
# 2018-09-09
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-15
# 2018-09-16
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-22
# 2018-09-23
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-09-29
# 2018-09-30
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-06
# 2018-10-07
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-13
# 2018-10-14
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-20
# 2018-10-21
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-27
# 2018-10-28
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-03
# 2018-11-04
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-10
# 2018-11-11
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-17
# 2018-11-18
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-22
# 2018-11-23
# 2018-11-24
# 2018-11-25
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-01
# 2018-12-02
# 2018-12-03
# 2018-12-04
# 2018-12-05
# 2018-12-06
# 2018-12-07
# 2018-12-08
# 2018-12-09
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-15
# 2018-12-16
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-22
# 2018-12-23
# 2018-12-24
# 2018-12-25
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-29
# 2018-12-30
# 2018-12-31
# 2019-01-01
# 2019-01-02
# 2019-01-03
# 2019-01-04
# 2019-01-05
# 2019-01-06
# 2019-01-07
# 2019-01-08
# 2019-01-09
# 2019-01-10
# 2019-01-11
# 2019-01-12
# 2019-01-13
# 2019-01-14
# 2019-01-15
# 2019-01-16
# 2019-01-17
# 2019-01-18
# 2019-01-19
# 2019-01-20
# 2019-01-21
# 2019-01-22
# 2019-01-23
# 2019-01-24
# 2019-01-25
# 2019-01-26
# 2019-01-27
# 2019-01-28
# 2019-01-29
# 2019-01-30
# 2019-01-31
# 2019-02-01
# 2019-02-02
# 2019-02-03
# 2019-02-04
# 2019-02-05
# 2019-02-06
# 2019-02-07
# 2019-02-08
# 2019-02-09
# 2019-02-10
# 2019-02-11
# 2019-02-12
# 2019-02-13
# 2019-02-14
# 2019-02-15
# 2019-02-16
# 2019-02-17
# 2019-02-18
# 2019-02-19
# 2019-02-20
# 2019-02-21
# 2019-02-22
# 2019-02-23
# 2019-02-24
# 2019-02-25
# 2019-02-26
# 2019-02-27
# 2019-02-28
# 2019-03-01
# 2019-03-02
# 2019-03-03
# 2019-03-04
# 2019-03-05
# 2019-03-06
# 2019-03-07
# 2019-03-08
# 2019-03-09
# 2019-03-10
# 2019-03-11
# 2019-03-12
# 2019-03-13
# 2019-03-14
# 2019-03-15
# 2019-03-16
# 2019-03-17
# 2019-03-18
# 2019-03-19
# 2019-03-20
# 2019-03-21
# 2019-03-22
# 2019-03-23
# 2019-03-24
# 2019-03-25
# 2019-03-26
# 2019-03-27
# 2019-03-28
# 2019-03-29
# 2019-03-30
# 2019-03-31
# 2019-04-01
# 2019-04-02
# 2019-04-03
# 2019-04-04
# 2019-04-05
# 2019-04-06
# 2019-04-07
# 2019-04-08
# 2019-04-09
# 2019-04-10
# 2019-04-11
# 2019-04-12
# 2019-04-13
# 2019-04-14
# 2019-04-15
# 2019-04-16
# 2019-04-17
# 2019-04-18
# 2019-04-19
# 2019-04-20
# 2019-04-21
# 2019-04-22
# 2019-04-23
# 2019-04-24
# 2019-04-25
# 2019-04-26
# 2019-04-27
# 2019-04-28
# 2019-04-29
# 2019-04-30
# 2019-05-01
# 2019-05-02
# 2019-05-03
# 2019-05-04
# 2019-05-05
# 2019-05-06
# 2019-05-07
# 2019-05-08
# 2019-05-09
# 2019-05-10
# 2019-05-11
# 2019-05-12
# 2019-05-13
# 2019-05-14
# 2019-05-15
# 2019-05-16
# 2019-05-17
# 2019-05-18
# 2019-05-19
# 2019-05-20
# 2019-05-21
# 2019-05-22
# 2019-05-23
# 2019-05-24
# 2019-05-25
# 2019-05-26
# 2019-05-27
# 2019-05-28
# 2019-05-29
# 2019-05-30
# 2019-05-31
# 2019-06-01
# 2019-06-02
# 2019-06-03
# 2019-06-04
# 2019-06-05
# 2019-06-06
# 2019-06-07
# 2019-06-08
# 2019-06-09
# 2019-06-10
# 2019-06-11
# 2019-06-12
# 2019-06-13
# 2019-06-14
# 2019-06-15
# 2019-06-16
# 2019-06-17
# 2019-06-18
# 2019-06-19
# 2019-06-20
# 2019-06-21
# 2019-06-22
# 2019-06-23
# 2019-06-24
# 2019-06-25
# 2019-06-26
# 2019-06-27
# 2019-06-28
# 2019-06-29
# 2019-06-30
# 2019-07-01
# 2019-07-02
# 2019-07-03
# 2019-07-04
# 2019-07-05
# 2019-07-06
# 2019-07-07
# 2019-07-08
# 2019-07-09
# 2019-07-10
# 2019-07-11
# 2019-07-12
# 2019-07-13
# 2019-07-14
# 2019-07-15
# 2019-07-16
# 2019-07-17
# 2019-07-18
# 2019-07-19
# 2019-07-20
# 2019-07-21
# 2019-07-22
# 2019-07-23
# 2019-07-24
# 2019-07-25
# 2019-07-26
# 2019-07-27
# 2019-07-28
# 2019-07-29
# 2019-07-30
# 2019-07-31
# 2019-08-01
# 2019-08-02
# 2019-08-03

# %%
df_wu

# %%
pd.to_csv()

# %% [markdown]
# ## 3. Análisis y curación de datos de un Excel y un TXT
#
# Referencias GLDAS: https://ldas.gsfc.nasa.gov/gldas
# Referencias IMERG: https://disasters.nasa.gov/instruments/imerg
#
#   1. Leer los datos de GLDAS_SantaRosa.xlsx para el período 1/Mayo/2018 al 31/Abril/2020.
#   2. Leer los datos de IMERG_SantaRosa.txt para el período 1/Mayo/2018 al 31/Abril/2020.
#   3. Hacer las conversiones de unidades necesarias a GLDAS para poder compararlos con "APRHi - Sta Rosa de Calamuchita".
#   4. Comparar los estadísticos de estos datasets con los de "APRHi - Sta Rosa de Calamuchita".

# %%
gldas_sta_rosa = pd.read_excel('dataset/Datos_Meteorologicos/GLDAS_SantaRosa.xlsx',
                               parse_dates=True,
                               index_col='Date')
gldas_sta_rosa.head()
# Out:
#                      Precip_mm  WND_mps  HMD_perc  TMP_Aire_Cels  ET_mm  \
# Date
# 2018-05-01 00:00:00      0.135    4.204    87.938         13.940  0.109
# 2018-05-01 03:00:00      0.243    3.106    89.098         13.860  0.098
# 2018-05-01 06:00:00      0.081    2.004    88.406         14.309  0.060
# 2018-05-01 09:00:00      0.089    1.405    89.872         14.585  0.048
# 2018-05-01 12:00:00      0.073    1.708    88.020         14.610  0.061
#
#                      Presion_hPa  Rad_Net_SW_MJpm2  Rad_Net_LW_MJpm2  \
# Date
# 2018-05-01 00:00:00    94890.477             1.152            39.873
# 2018-05-01 03:00:00    94948.945             0.000            39.999
# 2018-05-01 06:00:00    94844.109             0.000           -25.392
# 2018-05-01 09:00:00    94740.156             0.000            -4.457
# 2018-05-01 12:00:00    94789.625            64.728            -8.652
#
#                      HumedadSuelo_10a40cm  HumedadSuelo_0a10cm
# Date
# 2018-05-01 00:00:00                33.644               14.751
# 2018-05-01 03:00:00                33.813               14.733
# 2018-05-01 06:00:00                33.972               14.718
# 2018-05-01 09:00:00                34.122               14.704
# 2018-05-01 12:00:00                34.262               14.688

# %%
gldas_sta_rosa.index = gldas_sta_rosa.index.date

# %%
imerg_santa_rosa = pd.read_csv('dataset/Datos_Meteorologicos/IMERG_SantaRosa.txt',sep='\t',parse_dates=True,index_col='Date')
# imerg_santa_rosa.index = imerg_santa_rosa.index.date
imerg_santa_rosa.head()
# Out:
#                      Precip_mm
# Date
# 2018-05-01 00:00:00      0.000
# 2018-05-01 00:30:00      0.003
# 2018-05-01 01:00:00      0.000
# 2018-05-01 01:30:00      0.000
# 2018-05-01 02:00:00      0.000

# %%
gldas_sta_rosa['WND_mps'] = gldas_sta_rosa['WND_mps'].apply(lambda x: x * 3600 / 1000)

# %%
gldas_sta_rosa = gldas_sta_rosa.rename(columns={
    'Precip_mm': 'Lluvia_[mm]',
    'TMP_Aire_Cels': 'Temperatura_[Celsius]',
    'WND_mps': 'VelocidadViento_[KpH]',
})

# %%
gldas_sta_rosa['Lluvia_[mm]'].plot()
plt.xticks(rotation=45)
# Out:
# (array([736785., 736876., 736968., 737060., 737150., 737241., 737333.,
#         737425., 737516.]),
#  <a list of 9 Text xticklabel objects>)

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data=gldas_sta_rosa[['Lluvia_[mm]',
                                 'Temperatura_[Celsius]',
                                 'HMD_perc',
                                 'VelocidadViento_[KpH]']],color='green')
plt.xlabel('Variables')
plt.title('Diagrama de Cajas Variables Santa Rosa de Calamuchita')
plt.xticks(rotation=45)
sns.despine()

# %%
meteo_StaRosa = pd.read_csv("./dataset/Datos_Meteorologicos/APRHi - Sta Rosa de Calamuchita.csv", parse_dates=['date_time'])

# %%
meteo_StaRosa
# Out:
#        Codigo                         Estacion  dia  mes    anio       date  \
# 0       30234  APRHi - Sta Rosa de Calamuchita   15  8.0  2018.0  8/15/2018
# 1       30234  APRHi - Sta Rosa de Calamuchita   15  8.0  2018.0  8/15/2018
# 2       30234  APRHi - Sta Rosa de Calamuchita   15  8.0  2018.0  8/15/2018
# 3       30234  APRHi - Sta Rosa de Calamuchita   15  8.0  2018.0  8/15/2018
# 4       30234  APRHi - Sta Rosa de Calamuchita   15  8.0  2018.0  8/15/2018
# ...       ...                              ...  ...  ...     ...        ...
# 92466   30234  APRHi - Sta Rosa de Calamuchita   18  5.0  2020.0  5/18/2020
# 92467   30234  APRHi - Sta Rosa de Calamuchita   18  5.0  2020.0  5/18/2020
# 92468   30234  APRHi - Sta Rosa de Calamuchita   18  5.0  2020.0  5/18/2020
# 92469   30234  APRHi - Sta Rosa de Calamuchita   18  5.0  2020.0  5/18/2020
# 92470   30234  APRHi - Sta Rosa de Calamuchita   18  5.0  2020.0  5/18/2020
#
#         Hora         date_time  BUI_[adim]  Temperatura_[Celsius]  ...  \
# 0      13:00  08/15/2018 13:00         NaN                  18.79  ...
# 1      13:20  08/15/2018 13:20         NaN                  18.43  ...
# 2      13:30  08/15/2018 13:30         NaN                  18.01  ...
# 3      13:40  08/15/2018 13:40         NaN                  18.19  ...
# 4      13:50  08/15/2018 13:50         NaN                  18.31  ...
# ...      ...               ...         ...                    ...  ...
# 92466  17:20  05/18/2020 17:20         NaN                  27.00  ...
# 92467  17:30  05/18/2020 17:30         NaN                  26.68  ...
# 92468  17:40  05/18/2020 17:40         NaN                  26.24  ...
# 92469  17:50  05/18/2020 17:50         NaN                  25.73  ...
# 92470  18:00  05/18/2020 18:00         NaN                  25.04  ...
#
#        ISI_[adim]  FaseLunarAmanecerOcaso_[adim]  \
# 0             NaN                            NaN
# 1             NaN                            NaN
# 2             NaN                            NaN
# 3             NaN                            NaN
# 4             NaN                            NaN
# ...           ...                            ...
# 92466         NaN                            NaN
# 92467         NaN                            NaN
# 92468         NaN                            NaN
# 92469         NaN                            NaN
# 92470         NaN                            NaN
#
#        Alertas_Heladas_Agroapp_[adim]  Panel_Solar_[adim]  SenialGPRS_[ASU]  \
# 0                                 NaN                 NaN               5.0
# 1                                 NaN                 NaN               6.0
# 2                                 NaN                 NaN               6.0
# 3                                 NaN                 NaN               6.0
# 4                                 NaN                 NaN               6.0
# ...                               ...                 ...               ...
# 92466                             NaN                 NaN               5.0
# 92467                             NaN                 NaN               5.0
# 92468                             NaN                 NaN               5.0
# 92469                             NaN                 NaN               5.0
# 92470                             NaN                 NaN               5.0
#
#        IndicePeligroIncendios_[adim]  FFMC_[adim]  DMC_[adim]  DC_[adim]  \
# 0                                NaN          NaN         NaN        NaN
# 1                                NaN          NaN         NaN        NaN
# 2                                NaN          NaN         NaN        NaN
# 3                                NaN          NaN         NaN        NaN
# 4                                NaN          NaN         NaN        NaN
# ...                              ...          ...         ...        ...
# 92466                            NaN          NaN         NaN        NaN
# 92467                            NaN          NaN         NaN        NaN
# 92468                            NaN          NaN         NaN        NaN
# 92469                            NaN          NaN         NaN        NaN
# 92470                            NaN          NaN         NaN        NaN
#
#        NivelBateria_[V]
# 0               12.4427
# 1               13.1446
# 2               13.1446
# 3               13.1658
# 4               13.1658
# ...                 ...
# 92466           12.8255
# 92467           12.8255
# 92468           12.8042
# 92469           12.8468
# 92470           12.7830
#
# [92471 rows x 27 columns]

# %% [markdown]
# ## 4. Rellenar datos faltantes
#   1. ¿De todos los datasets comparados, para cada variable cuál se parece más a los de "APRHi - Sta Rosa de Calamuchita"?
#   2. Acumular las lluvias y promediar las demás variables de "APRHi - Sta Rosa de Calamuchita" cada 30 minutos.
#   3. Interpolar los datos ya procesados de las mejores fuentes de información "alternativas" (salvo las lluvias), cada 30 minutos.
#   4. Hacer lo mismo que en el punto anterior pero para la mejor fuente "alternativa" de lluvias, dividiendo por el número de "time-steps" equivalentes para llevar a cada dato a 30 minutos. (HINT: si la mejor es IMERG, no hacer nada ;D).
#   5. Interpolar el dataset "APRHi - Sta Rosa de Calamuchita" para rellenar los huecos.
#   6. Por otro lado, utilizar lo hecho en los punto 3 y 4 para rellenar los datos faltantes en la estación de "APRHi - Sta Rosa de Calamuchita".
#   7. Exportar los dos datasets nuevos en formato csv.
