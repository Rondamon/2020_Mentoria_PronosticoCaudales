# %% [markdown]
# ## CONSIGNA TP2:
#
# ## 1. Análisis y curación de datos de una API - formato JSON
#
# Referencias: https://darksky.net/dev/docs
#
#   1. Extraer los datos para la localidad Santa Rosa de Calamuchita para el período 1/Mayo/2018 al 01/Mayo/2020.
#   2. ¿Existen valores faltantes? Cuantificarlos.
#   3. Generar un nuevo dataset a partir de los datos (time, summary, precipAccumulation, temperature, humidity, pressure, windSpeed, uvIndex, temperatureMin, temperatureMax.
#   4. Hacer las conversiones de unidades necesarias a estos datos para poder compararlos con "APRHi - Sta Rosa de Calamuchita".
#   5. Comparar los estadísticos de estos datasets con los de "APRHi - Sta Rosa de Calamuchita".
#
#
# ## 2. Análisis y curación de datos Scrapeados de WeatherUnderground
#
# Referencias: https://www.wunderground.com/
#
#   1. Extraer los datos para la estación meteorológica personal (PWS, por siglas en inglés) "ICALAMUC5" (en Villa General Belgrano), para el período 1/Mayo/2018 al 01/Mayo/2020 mediante el Scrappeo de WeatherUnderground (WU).
#   2. ¿Existen valores faltantes? Cuantificarlos.
#   3. Convertir los datos faltantes en NaN.
#   4. Hacer las conversiones de unidades necesarias a estos datos para poder compararlos con "APRHi - Sta Rosa de Calamuchita".
#   5. Comparar los estadísticos de este dataset con los de "APRHi - Sta Rosa de Calamuchita".
#
#
# ## 3. Análisis y curación de datos de un Excel y un TXT
#
# Referencias GLDAS: https://ldas.gsfc.nasa.gov/gldas
# Referencias IMERG: https://disasters.nasa.gov/instruments/imerg
#
#   1. Leer los datos de GLDAS_SantaRosa.xlsx para el período 1/Mayo/2018 al 31/Abril/2020.
#   2. Leer los datos de IMERG_SantaRosa.txt para el período 1/Mayo/2018 al 31/Abril/2020.
#   3. Hacer las conversiones de unidades necesarias a GLDAS para poder compararlos con "APRHi - Sta Rosa de Calamuchita".
#   4. Comparar los estadísticos de estos datasets con los de "APRHi - Sta Rosa de Calamuchita".
#
#
# ## 4. Rellenar datos faltantes
#   1. ¿De todos los datasets comparados, para cada variable cuál se parece más a los de "APRHi - Sta Rosa de Calamuchita"?
#   2. Acumular las lluvias y promediar las demás variables de "APRHi - Sta Rosa de Calamuchita" cada 30 minutos.
#   3. Interpolar los datos ya procesados de las mejores fuentes de información "alternativas" (salvo las lluvias), cada 30 minutos.
#   4. Hacer lo mismo que en el punto anterior pero para la mejor fuente "alternativa" de lluvias, dividiendo por el número de "time-steps" equivalentes para llevar a cada dato a 30 minutos. (HINT: si la mejor es IMERG, no hacer nada ;D).
#   5. Interpolar el dataset "APRHi - Sta Rosa de Calamuchita" para rellenar los huecos.
#   6. Por otro lado, utilizar lo hecho en los punto 3 y 4 para rellenar los datos faltantes en la estación de "APRHi - Sta Rosa de Calamuchita".
#   7. Exportar los dos datasets nuevos en formato csv.

# %% [markdown]
# ## Ayuda Parte 1

# %%
import datetime
import requests
import pandas as pd
import json
from pandas import json_normalize

# %%
# This function returns a list of date between to boundaries. Source: https://stackoverflow.com/questions/1060279/iterating-through-a-range-of-dates-in-python
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + datetime.timedelta(n)

# %%
baseUrl = "https://api.darksky.net/forecast/<key>/<longitude>,<latitude>,<date>?exclude=flags,hourly&units=ca"

# %%
"""
En este bloque unicamente quise probar los metodos para pasar entre date, datetime y timestamp,
ya que son los formatos que se usan en la api.
Lo dejo aca porque tal vez le pueda ser ilustrativo a alguien
"""

start_date = datetime.datetime(2018, 5, 1)
end_date = datetime.datetime(2020, 5, 1)

for date in daterange(start_date, end_date):
        date2 = date.timestamp()
        tul = datetime.datetime.fromtimestamp(date2)
En este bloque se descarga la data y se la escribe en un archivo.
OJO! Cada vez que se ejecuta la funcion se sobre escribe el archivo con la data scrapeada.
"""

start_date = datetime.datetime(2018, 5, 1)
end_date = datetime.datetime(2018, 5, 5)

data = []
for date in daterange(start_date, end_date):
    tmstmp = str(int(date.timestamp()))
    replacedUrl = baseUrl.replace("<key>", "9349598e9f11f5eddceb6791daa6d787").replace("<longitude>", "-64.533333").replace("<latitude>", "-32.066667").replace("<date>",tmstmp)
    r = requests.get(url = replacedUrl)
    # json with day data
    partial_data = r.json()
    data.append(partial_data)
# writing json
with open('sta_rosa_scraped.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
with open('sta_rosa_scraped_last.json') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525143600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525230000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525316400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525402800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525489200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525575600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525662000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525748400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525834800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1525921200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526007600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526094000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526180400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526266800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526353200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526439600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526526000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526612400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526698800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526785200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526871600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1526958000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527044400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527130800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527217200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527303600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527390000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527476400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527562800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527649200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527735600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527822000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527908400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1527994800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528081200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528167600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528254000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528340400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528426800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528513200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528599600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528686000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528772400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528858800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1528945200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529031600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529118000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529204400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529290800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529377200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529463600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529550000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529636400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529722800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529809200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529895600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1529982000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530068400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530154800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530241200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530327600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530414000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530500400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530586800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530673200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530759600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530846000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1530932400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531018800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531105200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531191600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531278000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531364400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531450800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531537200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531623600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531710000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531796400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531882800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1531969200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532055600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532142000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532228400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532314800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532401200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532487600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532574000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532660400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532746800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532833200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1532919600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533006000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533092400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533178800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533265200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533351600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533438000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533524400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533610800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533697200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533783600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533870000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1533956400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534042800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534129200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534215600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534302000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534388400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534474800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534561200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534647600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534734000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534820400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534906800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1534993200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535079600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535166000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535252400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535338800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535425200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535511600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535598000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535684400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535770800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535857200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1535943600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536030000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536116400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536202800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536289200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536375600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536462000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536548400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536634800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536721200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536807600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536894000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1536980400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537066800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537153200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537239600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537326000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537412400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537498800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537585200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537671600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537758000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537844400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1537930800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538017200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538103600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538190000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538276400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538362800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538449200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538535600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538622000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538708400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538794800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538881200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1538967600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539054000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539140400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539226800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539313200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539399600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539486000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539572400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539658800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539745200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539831600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1539918000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540004400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540090800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540177200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540263600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540350000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540436400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540522800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540609200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540695600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540782000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540868400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1540954800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541041200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541127600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541214000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541300400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541386800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541473200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541559600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541646000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541732400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541818800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541905200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1541991600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542078000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542164400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542250800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542337200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542423600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542510000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542596400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542682800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542769200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542855600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1542942000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543028400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543114800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543201200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543287600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543374000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543460400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543546800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543633200, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543719600, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543806000, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543892400, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1543978800, 'uvIndex': 0},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544065200,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0961,
#    'precipProbability': 0.16,
#    'precipType': 'snow',
#    'precipAccumulation': 0.1095,
#    'temperature': -1.95,
#    'apparentTemperature': -4.17,
#    'dewPoint': -5.65,
#    'humidity': 0.76,
#    'pressure': 980.3,
#    'windSpeed': 5.83,
#    'windGust': 12,
#    'windBearing': 203,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 350},
#   'daily': {'data': [{'time': 1544061600,
#      'summary': 'Foggy overnight.',
#      'icon': 'snow',
#      'sunriseTime': 1544067600,
#      'sunsetTime': 1544142060,
#      'moonPhase': 0.99,
#      'precipIntensity': 0.0325,
#      'precipIntensityMax': 0.1313,
#      'precipIntensityMaxTime': 1544061600,
#      'precipProbability': 0.3,
#      'precipType': 'snow',
#      'precipAccumulation': 0.6,
#      'temperatureHigh': -0.11,
#      'temperatureHighTime': 1544123280,
#      'temperatureLow': -3.72,
#      'temperatureLowTime': 1544158560,
#      'apparentTemperatureHigh': -2.12,
#      'apparentTemperatureHighTime': 1544086800,
#      'apparentTemperatureLow': -11.64,
#      'apparentTemperatureLowTime': 1544159580,
#      'dewPoint': -5.96,
#      'humidity': 0.72,
#      'pressure': 982.8,
#      'windSpeed': 11.3,
#      'windGust': 22.38,
#      'windGustTime': 1544123160,
#      'windBearing': 283,
#      'cloudCover': 0.54,
#      'uvIndex': 4,
#      'uvIndexTime': 1544102700,
#      'visibility': 15.168,
#      'ozone': 334.5,
#      'temperatureMin': -3.17,
#      'temperatureMinTime': 1544076540,
#      'temperatureMax': -0.11,
#      'temperatureMaxTime': 1544123280,
#      'apparentTemperatureMin': -7.79,
#      'apparentTemperatureMinTime': 1544144400,
#      'apparentTemperatureMax': -2.05,
#      'apparentTemperatureMaxTime': 1544086020}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544151600,
#    'summary': 'Clear',
#    'icon': 'clear-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': -2.62,
#    'apparentTemperature': -9.21,
#    'dewPoint': -6.6,
#    'humidity': 0.74,
#    'pressure': 977.5,
#    'windSpeed': 24.65,
#    'windGust': 36.51,
#    'windBearing': 353,
#    'cloudCover': 0.29,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 317.4},
#   'daily': {'data': [{'time': 1544148000,
#      'summary': 'Snow (3–7 cm.) until evening.',
#      'icon': 'snow',
#      'sunriseTime': 1544153880,
#      'sunsetTime': 1544228700,
#      'moonPhase': 0.02,
#      'precipIntensity': 0.3722,
#      'precipIntensityMax': 1.0448,
#      'precipIntensityMaxTime': 1544175360,
#      'precipProbability': 0.74,
#      'precipType': 'snow',
#      'precipAccumulation': 4.4,
#      'temperatureHigh': 1.7,
#      'temperatureHighTime': 1544202000,
#      'temperatureLow': -0.48,
#      'temperatureLowTime': 1544244960,
#      'apparentTemperatureHigh': -4.81,
#      'apparentTemperatureHighTime': 1544201880,
#      'apparentTemperatureLow': -6.89,
#      'apparentTemperatureLowTime': 1544258400,
#      'dewPoint': -3.53,
#      'humidity': 0.78,
#      'pressure': 959.3,
#      'windSpeed': 37.46,
#      'windGust': 68.8,
#      'windGustTime': 1544173800,
#      'windBearing': 6,
#      'cloudCover': 0.87,
#      'uvIndex': 3,
#      'uvIndexTime': 1544190900,
#      'visibility': 4.08,
#      'ozone': 327,
#      'temperatureMin': -3.72,
#      'temperatureMinTime': 1544158560,
#      'temperatureMax': 1.7,
#      'temperatureMaxTime': 1544202000,
#      'apparentTemperatureMin': -11.64,
#      'apparentTemperatureMinTime': 1544159580,
#      'apparentTemperatureMax': -4.81,
#      'apparentTemperatureMaxTime': 1544201880}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544238000,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.2107,
#    'precipProbability': 0.2,
#    'precipType': 'snow',
#    'precipAccumulation': 0.2117,
#    'temperature': -0.07,
#    'apparentTemperature': -6.65,
#    'dewPoint': -3.52,
#    'humidity': 0.78,
#    'pressure': 949.3,
#    'windSpeed': 30.98,
#    'windGust': 49.07,
#    'windBearing': 354,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 1.988,
#    'ozone': 340.4},
#   'daily': {'data': [{'time': 1544234400,
#      'summary': 'Foggy in the morning.',
#      'icon': 'snow',
#      'sunriseTime': 1544240160,
#      'sunsetTime': 1544315280,
#      'moonPhase': 0.05,
#      'precipIntensity': 0.1088,
#      'precipIntensityMax': 0.2157,
#      'precipIntensityMaxTime': 1544234400,
#      'precipProbability': 0.44,
#      'precipType': 'snow',
#      'precipAccumulation': 1.4,
#      'temperatureHigh': 1.01,
#      'temperatureHighTime': 1544302500,
#      'temperatureLow': -2.67,
#      'temperatureLowTime': 1544335980,
#      'apparentTemperatureHigh': -5.79,
#      'apparentTemperatureHighTime': 1544277960,
#      'apparentTemperatureLow': -9.74,
#      'apparentTemperatureLowTime': 1544335320,
#      'dewPoint': -3.18,
#      'humidity': 0.78,
#      'pressure': 951.3,
#      'windSpeed': 32.02,
#      'windGust': 52.47,
#      'windGustTime': 1544317200,
#      'windBearing': 323,
#      'cloudCover': 0.99,
#      'uvIndex': 3,
#      'uvIndexTime': 1544277540,
#      'visibility': 8.743,
#      'ozone': 337.8,
#      'temperatureMin': -0.64,
#      'temperatureMinTime': 1544317200,
#      'temperatureMax': 1.01,
#      'temperatureMaxTime': 1544302500,
#      'apparentTemperatureMin': -7.31,
#      'apparentTemperatureMinTime': 1544317200,
#      'apparentTemperatureMax': -5.79,
#      'apparentTemperatureMaxTime': 1544277960}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544324400,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0479,
#    'precipProbability': 0.11,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0513,
#    'temperature': -1.02,
#    'apparentTemperature': -8.35,
#    'dewPoint': -5.54,
#    'humidity': 0.71,
#    'pressure': 961.2,
#    'windSpeed': 35.64,
#    'windGust': 52.59,
#    'windBearing': 288,
#    'cloudCover': 0.97,
#    'uvIndex': 0,
#    'visibility': 7.193,
#    'ozone': 334.4},
#   'daily': {'data': [{'time': 1544320800,
#      'summary': 'Mostly cloudy throughout the day.',
#      'icon': 'snow',
#      'sunriseTime': 1544326440,
#      'sunsetTime': 1544401860,
#      'moonPhase': 0.08,
#      'precipIntensity': 0.0184,
#      'precipIntensityMax': 0.0499,
#      'precipIntensityMaxTime': 1544322780,
#      'precipProbability': 0.28,
#      'precipType': 'snow',
#      'precipAccumulation': 0.3,
#      'temperatureHigh': 0.11,
#      'temperatureHighTime': 1544368920,
#      'temperatureLow': -3.18,
#      'temperatureLowTime': 1544418240,
#      'apparentTemperatureHigh': -5.16,
#      'apparentTemperatureHighTime': 1544388360,
#      'apparentTemperatureLow': -9.81,
#      'apparentTemperatureLowTime': 1544424000,
#      'dewPoint': -6.54,
#      'humidity': 0.67,
#      'pressure': 966.8,
#      'windSpeed': 25.85,
#      'windGust': 52.79,
#      'windGustTime': 1544321280,
#      'windBearing': 294,
#      'cloudCover': 0.79,
#      'uvIndex': 4,
#      'uvIndexTime': 1544359980,
#      'visibility': 13.662,
#      'ozone': 339.2,
#      'temperatureMin': -2.67,
#      'temperatureMinTime': 1544335980,
#      'temperatureMax': 0.11,
#      'temperatureMaxTime': 1544368920,
#      'apparentTemperatureMin': -9.74,
#      'apparentTemperatureMinTime': 1544335320,
#      'apparentTemperatureMax': -5.16,
#      'apparentTemperatureMaxTime': 1544388360}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544410800,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0116,
#    'precipProbability': 0.06,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0139,
#    'temperature': -2.65,
#    'apparentTemperature': -8.5,
#    'dewPoint': -7.91,
#    'humidity': 0.67,
#    'pressure': 971.3,
#    'windSpeed': 19.6,
#    'windGust': 33.35,
#    'windBearing': 287,
#    'cloudCover': 0.88,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 345.5},
#   'daily': {'data': [{'time': 1544407200,
#      'summary': 'Foggy in the morning.',
#      'icon': 'snow',
#      'sunriseTime': 1544412720,
#      'sunsetTime': 1544488380,
#      'moonPhase': 0.11,
#      'precipIntensity': 0.0429,
#      'precipIntensityMax': 0.1703,
#      'precipIntensityMaxTime': 1544443560,
#      'precipProbability': 0.37,
#      'precipType': 'snow',
#      'precipAccumulation': 0.8,
#      'temperatureHigh': 0.04,
#      'temperatureHighTime': 1544455140,
#      'temperatureLow': -5.65,
#      'temperatureLowTime': 1544502600,
#      'apparentTemperatureHigh': -7.08,
#      'apparentTemperatureHighTime': 1544475600,
#      'apparentTemperatureLow': -12.06,
#      'apparentTemperatureLowTime': 1544502180,
#      'dewPoint': -6.67,
#      'humidity': 0.68,
#      'pressure': 975.9,
#      'windSpeed': 29.48,
#      'windGust': 49.12,
#      'windGustTime': 1544448300,
#      'windBearing': 274,
#      'cloudCover': 0.9,
#      'uvIndex': 3,
#      'uvIndexTime': 1544448720,
#      'visibility': 14.942,
#      'ozone': 340.9,
#      'temperatureMin': -3.18,
#      'temperatureMinTime': 1544418240,
#      'temperatureMax': 0.04,
#      'temperatureMaxTime': 1544455140,
#      'apparentTemperatureMin': -9.81,
#      'apparentTemperatureMinTime': 1544424000,
#      'apparentTemperatureMax': -7.08,
#      'apparentTemperatureMaxTime': 1544475720}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544497200,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0126,
#    'precipProbability': 0.04,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0145,
#    'temperature': -2.13,
#    'apparentTemperature': -7.85,
#    'dewPoint': -7.93,
#    'humidity': 0.64,
#    'pressure': 983.1,
#    'windSpeed': 19.64,
#    'windGust': 33.33,
#    'windBearing': 279,
#    'cloudCover': 0.97,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 340.3},
#   'daily': {'data': [{'time': 1544493600,
#      'summary': 'Partly cloudy throughout the day.',
#      'icon': 'partly-cloudy-day',
#      'sunriseTime': 1544499000,
#      'sunsetTime': 1544574960,
#      'moonPhase': 0.14,
#      'precipIntensity': 0.0073,
#      'precipIntensityMax': 0.0195,
#      'precipIntensityMaxTime': 1544549160,
#      'precipProbability': 0.12,
#      'precipType': 'snow',
#      'precipAccumulation': 0.2,
#      'temperatureHigh': -0.63,
#      'temperatureHighTime': 1544561580,
#      'temperatureLow': -2.84,
#      'temperatureLowTime': 1544590440,
#      'apparentTemperatureHigh': -6.66,
#      'apparentTemperatureHighTime': 1544561940,
#      'apparentTemperatureLow': -8.79,
#      'apparentTemperatureLowTime': 1544590320,
#      'dewPoint': -7.94,
#      'humidity': 0.66,
#      'pressure': 986.6,
#      'windSpeed': 23.54,
#      'windGust': 35.28,
#      'windGustTime': 1544493600,
#      'windBearing': 262,
#      'cloudCover': 0.43,
#      'uvIndex': 5,
#      'uvIndexTime': 1544536620,
#      'visibility': 16.093,
#      'ozone': 328.9,
#      'temperatureMin': -5.65,
#      'temperatureMinTime': 1544502600,
#      'temperatureMax': -0.63,
#      'temperatureMaxTime': 1544561580,
#      'apparentTemperatureMin': -12.06,
#      'apparentTemperatureMinTime': 1544502180,
#      'apparentTemperatureMax': -6.66,
#      'apparentTemperatureMaxTime': 1544561940}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544583600,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0246,
#    'precipProbability': 0.05,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0286,
#    'temperature': -2.24,
#    'apparentTemperature': -8.41,
#    'dewPoint': -6.82,
#    'humidity': 0.71,
#    'pressure': 990,
#    'windSpeed': 22.36,
#    'windGust': 32.07,
#    'windBearing': 252,
#    'cloudCover': 0.99,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 318.2},
#   'daily': {'data': [{'time': 1544580000,
#      'summary': 'Mostly cloudy throughout the day.',
#      'icon': 'partly-cloudy-day',
#      'sunriseTime': 1544585280,
#      'sunsetTime': 1544661540,
#      'moonPhase': 0.17,
#      'precipIntensity': 0.0173,
#      'precipIntensityMax': 0.0418,
#      'precipIntensityMaxTime': 1544607120,
#      'precipProbability': 0.13,
#      'precipType': 'snow',
#      'precipAccumulation': 0.4,
#      'temperatureHigh': -0.63,
#      'temperatureHighTime': 1544633940,
#      'temperatureLow': -3.84,
#      'temperatureLowTime': 1544677080,
#      'apparentTemperatureHigh': -7.69,
#      'apparentTemperatureHighTime': 1544648280,
#      'apparentTemperatureLow': -10.27,
#      'apparentTemperatureLowTime': 1544676720,
#      'dewPoint': -6.5,
#      'humidity': 0.69,
#      'pressure': 992.2,
#      'windSpeed': 27.22,
#      'windGust': 39.6,
#      'windGustTime': 1544660400,
#      'windBearing': 236,
#      'cloudCover': 0.68,
#      'uvIndex': 4,
#      'uvIndexTime': 1544626440,
#      'visibility': 16.093,
#      'ozone': 326.9,
#      'temperatureMin': -2.84,
#      'temperatureMinTime': 1544590440,
#      'temperatureMax': -0.63,
#      'temperatureMaxTime': 1544633940,
#      'apparentTemperatureMin': -9.24,
#      'apparentTemperatureMinTime': 1544662800,
#      'apparentTemperatureMax': -7.69,
#      'apparentTemperatureMaxTime': 1544648280}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544670000,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': -3.1,
#    'apparentTemperature': -9.84,
#    'dewPoint': -7.84,
#    'humidity': 0.7,
#    'pressure': 994.1,
#    'windSpeed': 24.78,
#    'windGust': 37.13,
#    'windBearing': 246,
#    'cloudCover': 0.94,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 338.1},
#   'daily': {'data': [{'time': 1544666400,
#      'summary': 'Partly cloudy throughout the day.',
#      'icon': 'snow',
#      'sunriseTime': 1544671620,
#      'sunsetTime': 1544748060,
#      'moonPhase': 0.2,
#      'precipIntensity': 0.0253,
#      'precipIntensityMax': 0.1482,
#      'precipIntensityMaxTime': 1544735520,
#      'precipProbability': 0.26,
#      'precipType': 'snow',
#      'precipAccumulation': 0.2,
#      'temperatureHigh': 0.84,
#      'temperatureHighTime': 1544734800,
#      'temperatureLow': -0.63,
#      'temperatureLowTime': 1544762160,
#      'apparentTemperatureHigh': -4.94,
#      'apparentTemperatureHighTime': 1544734800,
#      'apparentTemperatureLow': -6.6,
#      'apparentTemperatureLowTime': 1544759700,
#      'dewPoint': -5.21,
#      'humidity': 0.74,
#      'pressure': 991.5,
#      'windSpeed': 22.48,
#      'windGust': 40.45,
#      'windGustTime': 1544749200,
#      'windBearing': 278,
#      'cloudCover': 0.53,
#      'uvIndex': 5,
#      'uvIndexTime': 1544707620,
#      'visibility': 15.923,
#      'ozone': 334,
#      'temperatureMin': -3.84,
#      'temperatureMinTime': 1544677080,
#      'temperatureMax': 1.1,
#      'temperatureMaxTime': 1544741160,
#      'apparentTemperatureMin': -10.27,
#      'apparentTemperatureMinTime': 1544676720,
#      'apparentTemperatureMax': -4.78,
#      'apparentTemperatureMaxTime': 1544740260}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1544756400,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0374,
#    'precipProbability': 0.04,
#    'precipType': 'rain',
#    'temperature': -0.18,
#    'apparentTemperature': -6.48,
#    'dewPoint': -3.44,
#    'humidity': 0.79,
#    'pressure': 984.6,
#    'windSpeed': 28.11,
#    'windGust': 42.8,
#    'windBearing': 282,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 330.4},
# ...
#      'precipIntensityMax': 0.7509,
#      'precipIntensityMaxTime': 1583480040,
#      'precipProbability': 0.85,
#      'precipType': 'rain',
#      'temperatureHigh': 1.94,
#      'temperatureHighTime': 1583494680,
#      'temperatureLow': -0.36,
#      'temperatureLowTime': 1583565300,
#      'apparentTemperatureHigh': -4.91,
#      'apparentTemperatureHighTime': 1583495220,
#      'apparentTemperatureLow': -7.62,
#      'apparentTemperatureLowTime': 1583557080,
#      'dewPoint': -1.88,
#      'humidity': 0.82,
#      'pressure': 978.5,
#      'windSpeed': 41.92,
#      'windGust': 70.72,
#      'windGustTime': 1583476920,
#      'windBearing': 313,
#      'cloudCover': 1,
#      'uvIndex': 2,
#      'uvIndexTime': 1583504340,
#      'visibility': 3.815,
#      'ozone': 280.3,
#      'temperatureMin': -0.13,
#      'temperatureMinTime': 1583460000,
#      'temperatureMax': 1.94,
#      'temperatureMaxTime': 1583494680,
#      'apparentTemperatureMin': -7.79,
#      'apparentTemperatureMinTime': 1583474400,
#      'apparentTemperatureMax': -4.91,
#      'apparentTemperatureMaxTime': 1583495220}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1583550000,
#    'summary': 'Windy and Overcast',
#    'icon': 'wind',
#    'precipIntensity': 0.5057,
#    'precipProbability': 0.18,
#    'precipType': 'rain',
#    'temperature': 0.28,
#    'apparentTemperature': -7.38,
#    'dewPoint': -2.11,
#    'humidity': 0.84,
#    'pressure': 968,
#    'windSpeed': 44.94,
#    'windGust': 59.31,
#    'windBearing': 248,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 0.097,
#    'ozone': 271.7},
#   'daily': {'data': [{'time': 1583546400,
#      'summary': 'Foggy in the morning.',
#      'icon': 'snow',
#      'sunriseTime': 1583566260,
#      'sunsetTime': 1583615400,
#      'moonPhase': 0.43,
#      'precipIntensity': 0.1722,
#      'precipIntensityMax': 0.6977,
#      'precipIntensityMaxTime': 1583559300,
#      'precipProbability': 0.51,
#      'precipType': 'snow',
#      'precipAccumulation': 1.8,
#      'temperatureHigh': 1.4,
#      'temperatureHighTime': 1583608140,
#      'temperatureLow': -0.97,
#      'temperatureLowTime': 1583654580,
#      'apparentTemperatureHigh': -4.56,
#      'apparentTemperatureHighTime': 1583583780,
#      'apparentTemperatureLow': -5.62,
#      'apparentTemperatureLowTime': 1583617920,
#      'dewPoint': -2.84,
#      'humidity': 0.78,
#      'pressure': 976,
#      'windSpeed': 31.78,
#      'windGust': 59.51,
#      'windGustTime': 1583552400,
#      'windBearing': 187,
#      'cloudCover': 1,
#      'uvIndex': 2,
#      'uvIndexTime': 1583590800,
#      'visibility': 10.508,
#      'ozone': 287.2,
#      'temperatureMin': -0.36,
#      'temperatureMinTime': 1583565300,
#      'temperatureMax': 1.4,
#      'temperatureMaxTime': 1583608140,
#      'apparentTemperatureMin': -7.62,
#      'apparentTemperatureMinTime': 1583557080,
#      'apparentTemperatureMax': -4.56,
#      'apparentTemperatureMaxTime': 1583583780}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1583636400,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0323,
#    'precipProbability': 0.03,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0319,
#    'temperature': 0.18,
#    'apparentTemperature': -5.21,
#    'dewPoint': -5.32,
#    'humidity': 0.67,
#    'pressure': 991.1,
#    'windSpeed': 21.55,
#    'windGust': 28.44,
#    'windBearing': 133,
#    'cloudCover': 0.99,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 290.9},
#   'daily': {'data': [{'time': 1583632800,
#      'summary': 'Foggy overnight.',
#      'icon': 'cloudy',
#      'sunriseTime': 1583652840,
#      'sunsetTime': 1583701620,
#      'moonPhase': 0.47,
#      'precipIntensity': 0.0165,
#      'precipIntensityMax': 0.0326,
#      'precipIntensityMaxTime': 1583637120,
#      'precipProbability': 0.18,
#      'precipType': 'snow',
#      'precipAccumulation': 0.2,
#      'temperatureHigh': 0.2,
#      'temperatureHighTime': 1583688960,
#      'temperatureLow': -1.04,
#      'temperatureLowTime': 1583728860,
#      'apparentTemperatureHigh': -2.57,
#      'apparentTemperatureHighTime': 1583685240,
#      'apparentTemperatureLow': -5.38,
#      'apparentTemperatureLowTime': 1583725020,
#      'dewPoint': -6.46,
#      'humidity': 0.63,
#      'pressure': 996,
#      'windSpeed': 12.38,
#      'windGust': 30.39,
#      'windGustTime': 1583632800,
#      'windBearing': 100,
#      'cloudCover': 1,
#      'uvIndex': 2,
#      'uvIndexTime': 1583677320,
#      'visibility': 15.559,
#      'ozone': 278.3,
#      'temperatureMin': -0.97,
#      'temperatureMinTime': 1583654580,
#      'temperatureMax': 0.72,
#      'temperatureMaxTime': 1583632800,
#      'apparentTemperatureMin': -5.32,
#      'apparentTemperatureMinTime': 1583641740,
#      'apparentTemperatureMax': -2.57,
#      'apparentTemperatureMaxTime': 1583685240}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1583722800,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0336,
#    'precipProbability': 0.05,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0349,
#    'temperature': -0.58,
#    'apparentTemperature': -5.34,
#    'dewPoint': -6.5,
#    'humidity': 0.64,
#    'pressure': 998.8,
#    'windSpeed': 16.23,
#    'windGust': 25.17,
#    'windBearing': 26,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 5.522,
#    'ozone': 273.8},
#   'daily': {'data': [{'time': 1583719200,
#      'summary': 'Foggy in the evening and overnight.',
#      'icon': 'snow',
#      'sunriseTime': 1583739420,
#      'sunsetTime': 1583787780,
#      'moonPhase': 0.51,
#      'precipIntensity': 0.0256,
#      'precipIntensityMax': 0.0503,
#      'precipIntensityMaxTime': 1583772780,
#      'precipProbability': 0.39,
#      'precipType': 'snow',
#      'precipAccumulation': 0.4,
#      'temperatureHigh': 0.09,
#      'temperatureHighTime': 1583754000,
#      'temperatureLow': -1.3,
#      'temperatureLowTime': 1583816040,
#      'apparentTemperatureHigh': -3.87,
#      'apparentTemperatureHighTime': 1583766900,
#      'apparentTemperatureLow': -7.84,
#      'apparentTemperatureLowTime': 1583826060,
#      'dewPoint': -4.2,
#      'humidity': 0.76,
#      'pressure': 998.2,
#      'windSpeed': 13.9,
#      'windGust': 25.18,
#      'windGustTime': 1583723220,
#      'windBearing': 56,
#      'cloudCover': 0.98,
#      'uvIndex': 2,
#      'uvIndexTime': 1583763540,
#      'visibility': 7.459,
#      'ozone': 279.3,
#      'temperatureMin': -1.04,
#      'temperatureMinTime': 1583728860,
#      'temperatureMax': 0.1,
#      'temperatureMaxTime': 1583796720,
#      'apparentTemperatureMin': -5.93,
#      'apparentTemperatureMinTime': 1583802000,
#      'apparentTemperatureMax': -3.87,
#      'apparentTemperatureMaxTime': 1583766900}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1583809200,
#    'summary': 'Overcast',
#    'icon': 'cloudy',
#    'precipIntensity': 0.0284,
#    'precipProbability': 0.05,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0302,
#    'temperature': -0.94,
#    'apparentTemperature': -7.59,
#    'dewPoint': -8.45,
#    'humidity': 0.57,
#    'pressure': 997.3,
#    'windSpeed': 29.08,
#    'windGust': 29.08,
#    'windBearing': 146,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 1.417,
#    'ozone': 268.7},
#   'daily': {'data': [{'time': 1583805600,
#      'summary': 'Foggy in the morning.',
#      'icon': 'snow',
#      'sunriseTime': 1583826000,
#      'sunsetTime': 1583873940,
#      'moonPhase': 0.55,
#      'precipIntensity': 0.0259,
#      'precipIntensityMax': 0.0518,
#      'precipIntensityMaxTime': 1583845020,
#      'precipProbability': 0.31,
#      'precipType': 'snow',
#      'precipAccumulation': 0.5,
#      'temperatureHigh': 0.05,
#      'temperatureHighTime': 1583840640,
#      'temperatureLow': -1.2,
#      'temperatureLowTime': 1583874000,
#      'apparentTemperatureHigh': -7.53,
#      'apparentTemperatureHighTime': 1583835720,
#      'apparentTemperatureLow': -7.56,
#      'apparentTemperatureLowTime': 1583874000,
#      'dewPoint': -7.03,
#      'humidity': 0.63,
#      'pressure': 998.7,
#      'windSpeed': 31.28,
#      'windGust': 39.82,
#      'windGustTime': 1583841780,
#      'windBearing': 152,
#      'cloudCover': 1,
#      'uvIndex': 2,
#      'uvIndexTime': 1583849880,
#      'visibility': 11.568,
#      'ozone': 276.8,
#      'temperatureMin': -1.42,
#      'temperatureMinTime': 1583861040,
#      'temperatureMax': 0.33,
#      'temperatureMaxTime': 1583888400,
#      'apparentTemperatureMin': -8.19,
#      'apparentTemperatureMinTime': 1583845860,
#      'apparentTemperatureMax': -5.79,
#      'apparentTemperatureMaxTime': 1583888400}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1583895600,
#    'summary': 'Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': -0.02,
#    'apparentTemperature': -5.63,
#    'dewPoint': -5.58,
#    'humidity': 0.66,
#    'pressure': 1001.5,
#    'windSpeed': 22.75,
#    'windGust': 26.41,
#    'windBearing': 197,
#    'cloudCover': 0.57,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 283},
#   'daily': {'data': [{'time': 1583892000,
#      'summary': 'Windy starting in the afternoon.',
#      'icon': 'partly-cloudy-day',
#      'sunriseTime': 1583912580,
#      'sunsetTime': 1583960160,
#      'moonPhase': 0.59,
#      'precipIntensity': 0.0041,
#      'precipIntensityMax': 0.0093,
#      'precipIntensityMaxTime': 1583924580,
#      'precipProbability': 0.15,
#      'precipType': 'snow',
#      'precipAccumulation': 0.1,
#      'temperatureHigh': 0.73,
#      'temperatureHighTime': 1583932680,
#      'temperatureLow': -0.1,
#      'temperatureLowTime': 1583960400,
#      'apparentTemperatureHigh': -6.97,
#      'apparentTemperatureHighTime': 1583931600,
#      'apparentTemperatureLow': -7.43,
#      'apparentTemperatureLowTime': 1583960400,
#      'dewPoint': -5.28,
#      'humidity': 0.67,
#      'pressure': 1002.8,
#      'windSpeed': 37.84,
#      'windGust': 56.21,
#      'windGustTime': 1583950680,
#      'windBearing': 222,
#      'cloudCover': 0.47,
#      'uvIndex': 2,
#      'uvIndexTime': 1583936760,
#      'visibility': 16.093,
#      'ozone': 283.3,
#      'temperatureMin': -0.44,
#      'temperatureMinTime': 1583912400,
#      'temperatureMax': 0.79,
#      'temperatureMaxTime': 1583974800,
#      'apparentTemperatureMin': -7.62,
#      'apparentTemperatureMinTime': 1583950980,
#      'apparentTemperatureMax': -5.6,
#      'apparentTemperatureMaxTime': 1583893920}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1583982000,
#    'summary': 'Windy and Mostly Cloudy',
#    'icon': 'wind',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 0.56,
#    'apparentTemperature': -6.69,
#    'dewPoint': -4.44,
#    'humidity': 0.69,
#    'pressure': 1004.2,
#    'windSpeed': 40.72,
#    'windGust': 49.6,
#    'windBearing': 229,
#    'cloudCover': 0.81,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 272.8},
#   'daily': {'data': [{'time': 1583978400,
#      'summary': 'Windy and partly cloudy throughout the day.',
#      'icon': 'wind',
#      'sunriseTime': 1583999160,
#      'sunsetTime': 1584046320,
#      'moonPhase': 0.63,
#      'precipIntensity': 0.0048,
#      'precipIntensityMax': 0.01,
#      'precipIntensityMaxTime': 1583991240,
#      'precipProbability': 0.17,
#      'precipType': 'rain',
#      'temperatureHigh': 1.79,
#      'temperatureHighTime': 1584041880,
#      'temperatureLow': -0.38,
#      'temperatureLowTime': 1584079200,
#      'apparentTemperatureHigh': -5.54,
#      'apparentTemperatureHighTime': 1584042660,
#      'apparentTemperatureLow': -8.24,
#      'apparentTemperatureLowTime': 1584079380,
#      'dewPoint': -3.76,
#      'humidity': 0.71,
#      'pressure': 1004.8,
#      'windSpeed': 41.82,
#      'windGust': 57.19,
#      'windGustTime': 1584061200,
#      'windBearing': 236,
#      'cloudCover': 0.45,
#      'uvIndex': 2,
#      'uvIndexTime': 1584022800,
#      'visibility': 16.093,
#      'ozone': 271.1,
#      'temperatureMin': 0.06,
#      'temperatureMinTime': 1583999760,
#      'temperatureMax': 1.79,
#      'temperatureMaxTime': 1584041880,
#      'apparentTemperatureMin': -7.03,
#      'apparentTemperatureMinTime': 1584000060,
#      'apparentTemperatureMax': -5.54,
#      'apparentTemperatureMaxTime': 1584042660}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1584068400,
#    'summary': 'Windy and Overcast',
#    'icon': 'wind',
#    'precipIntensity': 0.0246,
#    'precipProbability': 0.01,
#    'precipType': 'snow',
#    'precipAccumulation': 0.0241,
#    'temperature': 0.32,
#    'apparentTemperature': -7.49,
#    'dewPoint': -4.16,
#    'humidity': 0.72,
#    'pressure': 1006.3,
#    'windSpeed': 47.21,
#    'windGust': 56.98,
#    'windBearing': 240,
#    'cloudCover': 0.95,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 264.9},
#   'daily': {'data': [{'time': 1584064800,
#      'summary': 'Windy and mostly cloudy throughout the day.',
#      'icon': 'wind',
#      'sunriseTime': 1584085740,
#      'sunsetTime': 1584132540,
#      'moonPhase': 0.66,
#      'precipIntensity': 0.019,
#      'precipIntensityMax': 0.0355,
#      'precipIntensityMaxTime': 1584145320,
#      'precipProbability': 0.13,
#      'precipType': 'rain',
#      'temperatureHigh': 2.11,
#      'temperatureHighTime': 1584131880,
#      'temperatureLow': 0.84,
#      'temperatureLowTime': 1584169620,
#      'apparentTemperatureHigh': -5.62,
#      'apparentTemperatureHighTime': 1584131580,
#      'apparentTemperatureLow': -6.19,
#      'apparentTemperatureLowTime': 1584169380,
#      'dewPoint': -3.68,
#      'humidity': 0.71,
#      'pressure': 1006.2,
#      'windSpeed': 48.74,
#      'windGust': 70.02,
#      'windGustTime': 1584132000,
#      'windBearing': 251,
#      'cloudCover': 0.68,
#      'uvIndex': 2,
#      'uvIndexTime': 1584109860,
#      'visibility': 15.872,
#      'ozone': 263.2,
#      'temperatureMin': -0.38,
#      'temperatureMinTime': 1584079200,
#      'temperatureMax': 2.11,
#      'temperatureMaxTime': 1584131880,
#      'apparentTemperatureMin': -8.24,
#      'apparentTemperatureMinTime': 1584079380,
#      'apparentTemperatureMax': -5.62,
#      'apparentTemperatureMaxTime': 1584131580}]},
#   'offset': -2},
#  {'latitude': -64.533333,
#   'longitude': -32.066667,
#   'timezone': 'Etc/GMT+2',
#   'currently': {'time': 1584154800,
#    'summary': 'Windy and Overcast',
#    'icon': 'wind',
#    'precipIntensity': 0.031,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 1.34,
#    'apparentTemperature': -6.11,
#    'dewPoint': -2.57,
#    'humidity': 0.75,
#    'pressure': 1004.5,
#    'windSpeed': 47.15,
#    'windGust': 60.91,
#    'windBearing': 261,
#    'cloudCover': 1,
#    'uvIndex': 0,
#    'visibility': 16.093,
#    'ozone': 269},
#   'daily': {'data': [{'time': 1584151200,
#      'summary': 'Possible light rain overnight.',
#      'icon': 'wind',
#      'sunriseTime': 1584172320,
#      'sunsetTime': 1584218700,
#      'moonPhase': 0.7,
#      'precipIntensity': 0.0129,
#      'precipIntensityMax': 0.036,
#      'precipIntensityMaxTime': 1584151200,
#      'precipProbability': 0.24,
#      'precipType': 'rain',
#      'temperatureHigh': 1.54,
#      'temperatureHighTime': 1584186960,
#      'temperatureLow': -0.14,
#      'temperatureLowTime': 1584256440,
#      'apparentTemperatureHigh': -5.82,
#      'apparentTemperatureHighTime': 1584187140,
#      'apparentTemperatureLow': -7.95,
#      'apparentTemperatureLowTime': 1584258660,
#      'dewPoint': -2.64,
#      'humidity': 0.76,
#      'pressure': 1001.1,
#      'windSpeed': 42.13,
#      'windGust': 61.45,
#      'windGustTime': 1584151200,
#      'windBearing': 282,
#      'cloudCover': 0.95,
#      'uvIndex': 2,
#      'uvIndexTime': 1584195660,
#      'visibility': 16.093,
#      'ozone': 274.8,
#      'temperatureMin': 0.64,
#      'temperatureMinTime': 1584214680,
#      'temperatureMax': 1.7,
#      'temperatureMaxTime': 1584230340,
#      'apparentTemperatureMin': -6.19,
#      'apparentTemperatureMinTime': 1584169380,
#      'apparentTemperatureMax': -5.52,
#      'apparentTemperatureMaxTime': 1584230160}]},
#   'offset': -2}]

# %%
flatten_json = pd.json_normalize(data) # esta linea en teoria devuelve el json desanidado
flatten_json # pero como se ve toda la data anidada en la llave daily queda comprimida en daily.data.
# Out:
#       latitude  longitude   timezone  offset  currently.time  \
# 0   -64.533333 -32.066667  Etc/GMT+2      -2      1525143600
# 1   -64.533333 -32.066667  Etc/GMT+2      -2      1525230000
# 2   -64.533333 -32.066667  Etc/GMT+2      -2      1525316400
# 3   -64.533333 -32.066667  Etc/GMT+2      -2      1525402800
# 4   -64.533333 -32.066667  Etc/GMT+2      -2      1525489200
# ..         ...        ...        ...     ...             ...
# 679 -64.533333 -32.066667  Etc/GMT+2      -2      1583809200
# 680 -64.533333 -32.066667  Etc/GMT+2      -2      1583895600
# 681 -64.533333 -32.066667  Etc/GMT+2      -2      1583982000
# 682 -64.533333 -32.066667  Etc/GMT+2      -2      1584068400
# 683 -64.533333 -32.066667  Etc/GMT+2      -2      1584154800
#
#      currently.uvIndex        currently.summary       currently.icon  \
# 0                    0                      NaN                  NaN
# 1                    0                      NaN                  NaN
# 2                    0                      NaN                  NaN
# 3                    0                      NaN                  NaN
# 4                    0                      NaN                  NaN
# ..                 ...                      ...                  ...
# 679                  0                 Overcast               cloudy
# 680                  0            Partly Cloudy  partly-cloudy-night
# 681                  0  Windy and Mostly Cloudy                 wind
# 682                  0       Windy and Overcast                 wind
# 683                  0       Windy and Overcast                 wind
#
#      currently.precipIntensity  currently.precipProbability  ...  \
# 0                          NaN                          NaN  ...
# 1                          NaN                          NaN  ...
# 2                          NaN                          NaN  ...
# 3                          NaN                          NaN  ...
# 4                          NaN                          NaN  ...
# ..                         ...                          ...  ...
# 679                     0.0284                         0.05  ...
# 680                     0.0000                         0.00  ...
# 681                     0.0000                         0.00  ...
# 682                     0.0246                         0.01  ...
# 683                     0.0310                         0.02  ...
#
#     currently.dewPoint  currently.humidity  currently.pressure  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# ..                 ...                 ...                 ...
# 679              -8.45                0.57               997.3
# 680              -5.58                0.66              1001.5
# 681              -4.44                0.69              1004.2
# 682              -4.16                0.72              1006.3
# 683              -2.57                0.75              1004.5
#
#      currently.windSpeed  currently.windGust  currently.windBearing  \
# 0                    NaN                 NaN                    NaN
# 1                    NaN                 NaN                    NaN
# 2                    NaN                 NaN                    NaN
# 3                    NaN                 NaN                    NaN
# 4                    NaN                 NaN                    NaN
# ..                   ...                 ...                    ...
# 679                29.08               29.08                  146.0
# 680                22.75               26.41                  197.0
# 681                40.72               49.60                  229.0
# 682                47.21               56.98                  240.0
# 683                47.15               60.91                  261.0
#
#      currently.cloudCover  currently.visibility  currently.ozone  \
# 0                     NaN                   NaN              NaN
# 1                     NaN                   NaN              NaN
# 2                     NaN                   NaN              NaN
# 3                     NaN                   NaN              NaN
# 4                     NaN                   NaN              NaN
# ..                    ...                   ...              ...
# 679                  1.00                 1.417            268.7
# 680                  0.57                16.093            283.0
# 681                  0.81                16.093            272.8
# 682                  0.95                16.093            264.9
# 683                  1.00                16.093            269.0
#
#                                             daily.data
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 679  [{'time': 1583805600, 'summary': 'Foggy in the...
# 680  [{'time': 1583892000, 'summary': 'Windy starti...
# 681  [{'time': 1583978400, 'summary': 'Windy and pa...
# 682  [{'time': 1584064800, 'summary': 'Windy and mo...
# 683  [{'time': 1584151200, 'summary': 'Possible lig...
#
# [684 rows x 24 columns]

# %%
# identificar a partir de que fecha hay informacion, y luego descartar la informacion vacia

for n,dat in enumerate(data):
    try:
        if data[n]['daily']:
            print(n)
        break
    except KeyError:
        continue
# Out:
# 219

# %%
cleaned_json = data[219::]
flatten_json = pd.json_normalize(cleaned_json, ['daily','data'])
flatten_json.columns
# Out:
# Index(['time', 'summary', 'icon', 'sunriseTime', 'sunsetTime', 'moonPhase',
#        'precipIntensity', 'precipIntensityMax', 'precipIntensityMaxTime',
#        'precipProbability', 'precipType', 'precipAccumulation',
#        'temperatureHigh', 'temperatureHighTime', 'temperatureLow',
#        'temperatureLowTime', 'apparentTemperatureHigh',
#        'apparentTemperatureHighTime', 'apparentTemperatureLow',
#        'apparentTemperatureLowTime', 'dewPoint', 'humidity', 'pressure',
#        'windSpeed', 'windGust', 'windGustTime', 'windBearing', 'cloudCover',
#        'uvIndex', 'uvIndexTime', 'visibility', 'ozone', 'temperatureMin',
#        'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime',
#        'apparentTemperatureMin', 'apparentTemperatureMinTime',
#        'apparentTemperatureMax', 'apparentTemperatureMaxTime'],
#       dtype='object')

# %%
df = flatten_json[['time',
                   'summary',
                   'precipAccumulation',
                   'humidity',
                   'pressure',
                   'windSpeed',
                   'uvIndex',
                   'temperatureMin',
                   'temperatureMax']]

# %%
df.set_index('time').head()
# Out:
#                                       summary  precipAccumulation  humidity  \
# time
# 1544061600                   Foggy overnight.                 0.6      0.72
# 1544148000      Snow (3–7 cm.) until evening.                 4.4      0.78
# 1544234400              Foggy in the morning.                 1.4      0.78
# 1544320800  Mostly cloudy throughout the day.                 0.3      0.67
# 1544407200              Foggy in the morning.                 0.8      0.68
#
#             pressure  windSpeed  uvIndex  temperatureMin  temperatureMax
# time
# 1544061600     982.8      11.30        4           -3.17           -0.11
# 1544148000     959.3      37.46        3           -3.72            1.70
# 1544234400     951.3      32.02        3           -0.64            1.01
# 1544320800     966.8      25.85        4           -2.67            0.11
# 1544407200     975.9      29.48        3           -3.18            0.04

# %%
df2 = df

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/diplo/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2020-04-30'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-174-cb0339d91431> in <module>
# ----> 1 df2.index = df2[df2[datetime.datetime.fromtimestamp(date2).date().strftime("%Y-%m-%d")]]
#       2 df2
#
# ~/anaconda3/envs/diplo/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/envs/diplo/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2020-04-30'

# %%
first_day_data = df['time'][0]
date = datetime.datetime.fromtimestamp(first_day_data)
date.date().strftime("%Y-%m-%d")
# Out:
# '2018-12-05'

# %% [markdown]
# ## Ayuda Parte 2

# %%
#!pip3 install requests bs4

# %%
from bs4 import BeautifulSoup as bs
import requests
from urllib.request import urlopen
import datetime
import pandas as pd

# %%
stations = ["ICALAMUC5"]
start_date = datetime.date(2018, 9, 1)
end_date = datetime.date(2018, 9, 10) #Esta fecha no es incluida
rango = 'daily'

baseUrl = 'https://www.wunderground.com/dashboard/pws/<station>/table/<date>/<date>/daily'

# %%
tab_exist = 0
#stations_temp = []
  
for station in stations:
  print(station)
  for date in daterange(start_date, end_date):
    url = baseUrl.replace("<date>", date.strftime("%Y-%m-%d")).replace("<station>", station)
    page = bs(requests.get(url).content)
    response = requests.get(url)
    #if response != 200:
    #print(response)
    tabla = page.find('table', attrs={'class':'history-table desktop-table'})
    
    if tab_exist == 0:                

      
      print(response)
      print(date)
      #exist = 0
      
      if tabla:
        print('Hay datos', date, station)
        tab_exist = 1
        #Creo lista con el nombre de las columnas
        list_html = tabla.find_all('th')
        #lista con las unidades
        list_unid = ['','C','C','%','','km/h','km/h','hPa','mm','mm','','']
        list_col = []
        for i in list_html:
          col_temp = i.string
          list_col.append(col_temp)
        for j in range(len(list_col)):
          if list_unid[j]:          
            list_col[j] = list_col[j] + '[' + list_unid[j] + ']'
            #list_col[j] = list_col[j].strip('()')

        df_wu = pd.DataFrame(columns = list_col )
  
  
    if tab_exist == 1:    #Entra acá cuando ya se creo la lista con los parametros
      print(date)
      #Entra acá cuando ya se creo la lista
      if response.status_code == 200:
        if tabla:
          m = tabla.tbody.find_all('tr')
          m_val = []
          for i in m:
            list_temp = []
            l_html = i.find_all('td')
            
            for j in range(0,len(l_html)): 
              if j == 0:
                
                list_temp.append(date.strftime("%Y-%m-%d") +' '+ l_html[j].string)            
                        
              elif j == 4 or j == 10 or j == 11: 
                list_temp.append(l_html[j].string) 
              else:
                list_temp.append(l_html[j].span.span.string)

            m_val.append(list_temp) #Matriz con los valores

          df_temp = pd.DataFrame(m_val, columns=list_col)  #Transformo la matriz en un DataFrame
      #df_temp.rename(columns={0:'Time'})
          #for i in range(0,len(m_val[0])):
            #df_temp.rename(columns={i:list_col[i]}, inplace=True)
          df_temp['Station'] = station
          df_temp['Date'] = date

          df_wu =pd.concat([df_wu,df_temp], axis=0)
      else:
        print(response)

# %%
df_wu
